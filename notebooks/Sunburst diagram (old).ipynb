# %% [markdown]
# # Sunburst diagram

# %%
from neo4j import GraphDatabase
import logging
from neo4j.exceptions import ServiceUnavailable
import streamlit as st
class App:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        # Don't forget to close the driver connection when you are finished with it
        self.driver.close()

    

    def find_pattern(self, query_string):
        with self.driver.session() as session:
            result = session.read_transaction(self._find_and_return_pattern, query_string)
            for row in result:
                return row["cnt"]


    @staticmethod
    def _find_and_return_pattern(tx, query_string):
        result = tx.run(query_string+" as cnt")
        return [row for row in result]

# %%
def all_teams():
    return {'Austria',
     'Belgium',
     'Croatia',
     'Czech_Republic',
     'Denmark',
     'England',
     'Finland',
     'France',
     'Germany',
     'Hungary',
     'Italy',
     'Netherlands',
     'MACEDONIA_REPUBLIC_OF',
     'Poland',
     'Portugal',
     'Russia',
     'Scotland',
     'Slovakia',
     'Spain',
     'Sweden',
     'Switzerland',
     'Turkey',
     'Ukraine',
     'Wales'}

# %%
def cypherify(string, team = None):
    letters = list(string)

    if team:
        query = "MATCH p=(A:"+team+")"
        for i in range(len(string) - 1):
            query += "-[p" + str(i) + ":PASS]->(" + letters[i + 1] + ":"+team+")"
    else:
        query = "MATCH (A)"
        for i in range(len(string) - 1):
            query += "-[p" + str(i) + ":PASS]->(" + letters[i + 1] + ")"

    query += "\nWHERE "

    #correct order
    first = True
    for i in range(len(string) - 2):
        if first:
            query += "p" + str(i) + ".order + 1 = p" + str(i + 1) + ".order"
            first = False
        else:
            query += " and p" + str(i) + ".order + 1 = p" + str(i + 1) + ".order"

    #same possession
    first = True
    for i in range(len(string) - 2):
        if first:
            query += " and p" + str(i) + ".possession = p" + str(i + 1) + ".possession"
            first = False
        else:
            query += " and p" + str(i) + ".possession = p" + str(i + 1) + ".possession"

    #same match
    first = True
    for i in range(len(string) - 2):
        if first:
            query += " and p" + str(i) + ".match_id = p" + str(i + 1) + ".match_id"
            first = False
        else:
            query += " and p" + str(i) + ".match_id = p" + str(i + 1) + ".match_id"

    #different players
    unorderedPairGenerator = ((x, y) for x in set(letters) for y in set(letters) if y > x)
    if string != "AB":
        query += " and " + " and ".join([x + ".name <>" + " " +y + ".name" for x, y in list(unorderedPairGenerator)])
    else:
        query +=  " and ".join([x + ".name <>" + " " +y + ".name" for x, y in list(unorderedPairGenerator)])
    
    
    query += "\nRETURN COUNT(p)"
    return query

# %%
cypherify("AB", "ITALY")
# Out:
# 'MATCH p=(A:ITALY)-[p0:PASS]->(B:ITALY)\nWHERE A.name <> B.name\nRETURN COUNT(p)'

# %%
result = {}
for key in all_teams():
    result[key.upper()] = {}

# %%
def get_value(pattern, team, app):
    query = cypherify(pattern, team)
    v = app.find_pattern(query)
    #print("Pattern: "+pattern+" \t Value: "+str(v))
    result[team][pattern] = v
    return v

# %%
team = "ITALY"
uri = "neo4j+s://00e145e7.databases.neo4j.io:7687"
user = "soccer_analytics"
password = "night-candle-miracle-nickel-declare-32"
app = App(uri, user, password)

def isNet(array):
    vect = [0]*len(array)
    return pass_net_check(1, len(array),vect, array)


def pass_net(i,n, vect, team, app):
    #print("------")
    
    if i==1:
        vect[i-1] = "A"
        pass_net(2,n,vect, team, app)
    elif i==2:
        vect[i-1] = "B"
        v = get_value("".join(vect[:i]), team, app)
        if v>0:
            pass_net(3,n,vect, team, app)
    elif i==n+1:
        #print("".join(vect))
        return
    else:
        for l in distinct_letters(vect, i-2):
            vect[i-1] = l
            v = get_value("".join(vect[:i]), team, app)
            if v > 0:
                pass_net(i+1,n,vect, team, app)
        vect[i-1] = first_new_letter(vect,i-1)
        v = get_value("".join(vect[:i]), team, app)
        if v > 0:
            pass_net(i+1,n,vect, team, app)

def first_new_letter(vect,end):
    letters = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "L", "M"]
    max_letter = max(vect[:end])
    return letters[letters.index(max_letter)+1]

def distinct_letters(vect, end):
    el = set(vect[:end])
    el.discard(vect[end])
    return list(el)

# %%
for team in all_teams():
    print("Team: "+team)
    team = team.upper()
    n = 6
    l = [0]*n
    pass_net(1, n, l, team, app)
# Out:
# Team: Portugal
# Team: Scotland
# Team: Italy
# Team: England
# Team: Spain
# Team: Slovakia
# Team: Wales
# Team: Croatia
# Team: MACEDONIA_REPUBLIC_OF
# Team: Czech_Republic
# Team: Turkey
# Team: Poland
# Team: Belgium
# Team: Finland
# Team: Germany
# Team: Ukraine
# Team: Austria
# Team: Netherlands
# Team: Hungary
# Team: Sweden
# Team: Switzerland
# Team: Denmark
# Team: France
# Team: Russia

# %%
result
# Out:
# {'PORTUGAL': {'AB': 2117,
#   'ABA': 312,
#   'ABAB': 54,
#   'ABABA': 10,
#   'ABABAB': 2,
#   'ABABAC': 6,
#   'ABABC': 36,
#   'ABABCA': 5,
#   'ABABCB': 6,
#   'ABABCD': 19,
#   'ABAC': 216,
#   'ABACA': 31,
#   'ABACAC': 4,
#   'ABACAB': 6,
#   'ABACAD': 19,
#   'ABACB': 22,
#   'ABACBA': 2,
#   'ABACBC': 3,
#   'ABACBD': 15,
#   'ABACD': 122,
#   'ABACDA': 5,
#   'ABACDC': 16,
#   'ABACDB': 9,
#   'ABACDE': 70,
#   'ABC': 1470,
#   'ABCA': 121,
#   'ABCAC': 14,
#   'ABCACA': 3,
#   'ABCACB': 4,
#   'ABCACD': 6,
#   'ABCAB': 17,
#   'ABCABA': 2,
#   'ABCABC': 3,
#   'ABCABD': 8,
#   'ABCAD': 76,
#   'ABCADA': 10,
#   'ABCADC': 9,
#   'ABCADB': 5,
#   'ABCADE': 40,
#   'ABCB': 198,
#   'ABCBA': 31,
#   'ABCBAC': 2,
#   'ABCBAB': 5,
#   'ABCBAD': 23,
#   'ABCBC': 38,
#   'ABCBCA': 5,
#   'ABCBCB': 7,
#   'ABCBCD': 21,
#   'ABCBD': 108,
#   'ABCBDA': 7,
#   'ABCBDC': 13,
#   'ABCBDB': 13,
#   'ABCBDE': 51,
#   'ABCD': 890,
#   'ABCDA': 67,
#   'ABCDAC': 9,
#   'ABCDAD': 7,
#   'ABCDAB': 7,
#   'ABCDAE': 35,
#   'ABCDC': 115,
#   'ABCDCA': 17,
#   'ABCDCD': 23,
#   'ABCDCB': 19,
#   'ABCDCE': 42,
#   'ABCDB': 64,
#   'ABCDBA': 10,
#   'ABCDBC': 8,
#   'ABCDBD': 4,
#   'ABCDBE': 37,
#   'ABCDE': 478,
#   'ABCDEA': 42,
#   'ABCDEC': 36,
#   'ABCDED': 60,
#   'ABCDEB': 39,
#   'ABCDEF': 210},
#  'SCOTLAND': {'AB': 1104,
#   'ABA': 104,
#   'ABAB': 10,
#   'ABABA': 2,
#   'ABABAB': 0,
#   'ABABAC': 2,
#   'ABABC': 6,
#   'ABABCA': 2,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 80,
#   'ABACA': 9,
#   'ABACAC': 2,
#   'ABACAB': 1,
#   'ABACAD': 6,
#   'ABACB': 8,
#   'ABACBA': 0,
#   'ABACBC': 3,
#   'ABACBD': 5,
#   'ABACD': 35,
#   'ABACDA': 3,
#   'ABACDC': 1,
#   'ABACDB': 2,
#   'ABACDE': 20,
#   'ABC': 737,
#   'ABCA': 54,
#   'ABCAC': 8,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 6,
#   'ABCAB': 8,
#   'ABCABA': 2,
#   'ABCABC': 0,
#   'ABCABD': 5,
#   'ABCAD': 28,
#   'ABCADA': 1,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 17,
#   'ABCB': 68,
#   'ABCBA': 9,
#   'ABCBAC': 2,
#   'ABCBAB': 1,
#   'ABCBAD': 5,
#   'ABCBC': 4,
#   'ABCBCA': 0,
#   'ABCBCB': 1,
#   'ABCBCD': 2,
#   'ABCBD': 45,
#   'ABCBDA': 4,
#   'ABCBDC': 4,
#   'ABCBDB': 7,
#   'ABCBDE': 17,
#   'ABCD': 419,
#   'ABCDA': 27,
#   'ABCDAC': 3,
#   'ABCDAD': 2,
#   'ABCDAB': 4,
#   'ABCDAE': 14,
#   'ABCDC': 35,
#   'ABCDCA': 5,
#   'ABCDCD': 0,
#   'ABCDCB': 6,
#   'ABCDCE': 18,
#   'ABCDB': 31,
#   'ABCDBA': 4,
#   'ABCDBC': 5,
#   'ABCDBD': 3,
#   'ABCDBE': 13,
#   'ABCDE': 220,
#   'ABCDEA': 17,
#   'ABCDEC': 16,
#   'ABCDED': 17,
#   'ABCDEB': 12,
#   'ABCDEF': 102},
#  'ITALY': {'AB': 4107,
#   'ABA': 589,
#   'ABAB': 89,
#   'ABABA': 13,
#   'ABABAB': 2,
#   'ABABAC': 9,
#   'ABABC': 63,
#   'ABABCA': 7,
#   'ABABCB': 5,
#   'ABABCD': 38,
#   'ABAC': 420,
#   'ABACA': 57,
#   'ABACAC': 12,
#   'ABACAB': 16,
#   'ABACAD': 24,
#   'ABACB': 31,
#   'ABACBA': 7,
#   'ABACBC': 4,
#   'ABACBD': 16,
#   'ABACD': 255,
#   'ABACDA': 17,
#   'ABACDC': 41,
#   'ABACDB': 18,
#   'ABACDE': 127,
#   'ABC': 2815,
#   'ABCA': 245,
#   'ABCAC': 36,
#   'ABCACA': 8,
#   'ABCACB': 4,
#   'ABCACD': 18,
#   'ABCAB': 36,
#   'ABCABA': 7,
#   'ABCABC': 7,
#   'ABCABD': 17,
#   'ABCAD': 148,
#   'ABCADA': 26,
#   'ABCADC': 15,
#   'ABCADB': 12,
#   'ABCADE': 78,
#   'ABCB': 394,
#   'ABCBA': 70,
#   'ABCBAC': 3,
#   'ABCBAB': 13,
#   'ABCBAD': 48,
#   'ABCBC': 57,
#   'ABCBCA': 4,
#   'ABCBCB': 6,
#   'ABCBCD': 41,
#   'ABCBD': 219,
#   'ABCBDA': 27,
#   'ABCBDC': 18,
#   'ABCBDB': 34,
#   'ABCBDE': 103,
#   'ABCD': 1626,
#   'ABCDA': 97,
#   'ABCDAC': 9,
#   'ABCDAD': 12,
#   'ABCDAB': 13,
#   'ABCDAE': 52,
#   'ABCDC': 238,
#   'ABCDCA': 34,
#   'ABCDCD': 28,
#   'ABCDCB': 45,
#   'ABCDCE': 104,
#   'ABCDB': 136,
#   'ABCDBA': 22,
#   'ABCDBC': 19,
#   'ABCDBD': 18,
#   'ABCDBE': 65,
#   'ABCDE': 800,
#   'ABCDEA': 38,
#   'ABCDEC': 68,
#   'ABCDED': 108,
#   'ABCDEB': 34,
#   'ABCDEF': 347},
#  'ENGLAND': {'AB': 3588,
#   'ABA': 552,
#   'ABAB': 76,
#   'ABABA': 15,
#   'ABABAB': 2,
#   'ABABAC': 12,
#   'ABABC': 57,
#   'ABABCA': 4,
#   'ABABCB': 10,
#   'ABABCD': 37,
#   'ABAC': 415,
#   'ABACA': 56,
#   'ABACAC': 8,
#   'ABACAB': 12,
#   'ABACAD': 30,
#   'ABACB': 32,
#   'ABACBA': 3,
#   'ABACBC': 4,
#   'ABACBD': 18,
#   'ABACD': 271,
#   'ABACDA': 16,
#   'ABACDC': 48,
#   'ABACDB': 10,
#   'ABACDE': 161,
#   'ABC': 2456,
#   'ABCA': 190,
#   'ABCAC': 29,
#   'ABCACA': 5,
#   'ABCACB': 2,
#   'ABCACD': 22,
#   'ABCAB': 21,
#   'ABCABA': 4,
#   'ABCABC': 1,
#   'ABCABD': 15,
#   'ABCAD': 121,
#   'ABCADA': 14,
#   'ABCADC': 3,
#   'ABCADB': 4,
#   'ABCADE': 78,
#   'ABCB': 386,
#   'ABCBA': 79,
#   'ABCBAC': 7,
#   'ABCBAB': 15,
#   'ABCBAD': 54,
#   'ABCBC': 52,
#   'ABCBCA': 9,
#   'ABCBCB': 12,
#   'ABCBCD': 28,
#   'ABCBD': 211,
#   'ABCBDA': 22,
#   'ABCBDC': 17,
#   'ABCBDB': 27,
#   'ABCBDE': 118,
#   'ABCD': 1455,
#   'ABCDA': 71,
#   'ABCDAC': 7,
#   'ABCDAD': 9,
#   'ABCDAB': 10,
#   'ABCDAE': 33,
#   'ABCDC': 249,
#   'ABCDCA': 19,
#   'ABCDCD': 33,
#   'ABCDCB': 58,
#   'ABCDCE': 111,
#   'ABCDB': 117,
#   'ABCDBA': 22,
#   'ABCDBC': 16,
#   'ABCDBD': 19,
#   'ABCDBE': 52,
#   'ABCDE': 749,
#   'ABCDEA': 31,
#   'ABCDEC': 74,
#   'ABCDED': 138,
#   'ABCDEB': 31,
#   'ABCDEF': 325},
#  'SPAIN': {'AB': 4966,
#   'ABA': 669,
#   'ABAB': 90,
#   'ABABA': 15,
#   'ABABAB': 2,
#   'ABABAC': 12,
#   'ABABC': 68,
#   'ABABCA': 7,
#   'ABABCB': 10,
#   'ABABCD': 42,
#   'ABAC': 516,
#   'ABACA': 74,
#   'ABACAC': 8,
#   'ABACAB': 16,
#   'ABACAD': 45,
#   'ABACB': 36,
#   'ABACBA': 1,
#   'ABACBC': 7,
#   'ABACBD': 22,
#   'ABACD': 335,
#   'ABACDA': 18,
#   'ABACDC': 31,
#   'ABACDB': 15,
#   'ABACDE': 223,
#   'ABC': 3584,
#   'ABCA': 276,
#   'ABCAC': 33,
#   'ABCACA': 4,
#   'ABCACB': 1,
#   'ABCACD': 24,
#   'ABCAB': 28,
#   'ABCABA': 5,
#   'ABCABC': 4,
#   'ABCABD': 18,
#   'ABCAD': 187,
#   'ABCADA': 22,
#   'ABCADC': 12,
#   'ABCADB': 13,
#   'ABCADE': 110,
#   'ABCB': 492,
#   'ABCBA': 104,
#   'ABCBAC': 7,
#   'ABCBAB': 16,
#   'ABCBAD': 78,
#   'ABCBC': 53,
#   'ABCBCA': 5,
#   'ABCBCB': 12,
#   'ABCBCD': 34,
#   'ABCBD': 287,
#   'ABCBDA': 37,
#   'ABCBDC': 14,
#   'ABCBDB': 41,
#   'ABCBDE': 150,
#   'ABCD': 2246,
#   'ABCDA': 123,
#   'ABCDAC': 10,
#   'ABCDAD': 13,
#   'ABCDAB': 11,
#   'ABCDAE': 69,
#   'ABCDC': 317,
#   'ABCDCA': 29,
#   'ABCDCD': 36,
#   'ABCDCB': 77,
#   'ABCDCE': 143,
#   'ABCDB': 161,
#   'ABCDBA': 35,
#   'ABCDBC': 19,
#   'ABCDBD': 16,
#   'ABCDBE': 75,
#   'ABCDE': 1253,
#   'ABCDEA': 61,
#   'ABCDEC': 93,
#   'ABCDED': 200,
#   'ABCDEB': 68,
#   'ABCDEF': 594},
#  'SLOVAKIA': {'AB': 1271,
#   'ABA': 184,
#   'ABAB': 17,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 14,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 8,
#   'ABAC': 147,
#   'ABACA': 23,
#   'ABACAC': 0,
#   'ABACAB': 4,
#   'ABACAD': 16,
#   'ABACB': 6,
#   'ABACBA': 0,
#   'ABACBC': 2,
#   'ABACBD': 2,
#   'ABACD': 94,
#   'ABACDA': 10,
#   'ABACDC': 22,
#   'ABACDB': 2,
#   'ABACDE': 48,
#   'ABC': 868,
#   'ABCA': 60,
#   'ABCAC': 7,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 4,
#   'ABCAB': 9,
#   'ABCABA': 1,
#   'ABCABC': 2,
#   'ABCABD': 6,
#   'ABCAD': 37,
#   'ABCADA': 7,
#   'ABCADC': 1,
#   'ABCADB': 0,
#   'ABCADE': 25,
#   'ABCB': 136,
#   'ABCBA': 23,
#   'ABCBAC': 1,
#   'ABCBAB': 5,
#   'ABCBAD': 15,
#   'ABCBC': 13,
#   'ABCBCA': 0,
#   'ABCBCB': 1,
#   'ABCBCD': 10,
#   'ABCBD': 85,
#   'ABCBDA': 9,
#   'ABCBDC': 5,
#   'ABCBDB': 15,
#   'ABCBDE': 43,
#   'ABCD': 503,
#   'ABCDA': 24,
#   'ABCDAC': 0,
#   'ABCDAD': 4,
#   'ABCDAB': 1,
#   'ABCDAE': 15,
#   'ABCDC': 87,
#   'ABCDCA': 4,
#   'ABCDCD': 11,
#   'ABCDCB': 16,
#   'ABCDCE': 47,
#   'ABCDB': 40,
#   'ABCDBA': 4,
#   'ABCDBC': 7,
#   'ABCDBD': 3,
#   'ABCDBE': 22,
#   'ABCDE': 259,
#   'ABCDEA': 10,
#   'ABCDEC': 24,
#   'ABCDED': 33,
#   'ABCDEB': 18,
#   'ABCDEF': 112},
#  'WALES': {'AB': 1143,
#   'ABA': 118,
#   'ABAB': 11,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 0,
#   'ABABC': 9,
#   'ABABCA': 1,
#   'ABABCB': 1,
#   'ABABCD': 5,
#   'ABAC': 89,
#   'ABACA': 9,
#   'ABACAC': 1,
#   'ABACAB': 2,
#   'ABACAD': 5,
#   'ABACB': 4,
#   'ABACBA': 2,
#   'ABACBC': 0,
#   'ABACBD': 2,
#   'ABACD': 47,
#   'ABACDA': 2,
#   'ABACDC': 5,
#   'ABACDB': 1,
#   'ABACDE': 28,
#   'ABC': 766,
#   'ABCA': 58,
#   'ABCAC': 2,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 2,
#   'ABCAB': 8,
#   'ABCABA': 0,
#   'ABCABC': 3,
#   'ABCABD': 3,
#   'ABCAD': 38,
#   'ABCADA': 1,
#   'ABCADC': 3,
#   'ABCADB': 3,
#   'ABCADE': 18,
#   'ABCB': 79,
#   'ABCBA': 16,
#   'ABCBAC': 1,
#   'ABCBAB': 3,
#   'ABCBAD': 6,
#   'ABCBC': 7,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 7,
#   'ABCBD': 44,
#   'ABCBDA': 1,
#   'ABCBDC': 2,
#   'ABCBDB': 5,
#   'ABCBDE': 20,
#   'ABCD': 422,
#   'ABCDA': 18,
#   'ABCDAC': 1,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 10,
#   'ABCDC': 44,
#   'ABCDCA': 4,
#   'ABCDCD': 5,
#   'ABCDCB': 7,
#   'ABCDCE': 22,
#   'ABCDB': 38,
#   'ABCDBA': 4,
#   'ABCDBC': 3,
#   'ABCDBD': 2,
#   'ABCDBE': 23,
#   'ABCDE': 204,
#   'ABCDEA': 9,
#   'ABCDEC': 22,
#   'ABCDED': 24,
#   'ABCDEB': 10,
#   'ABCDEF': 81},
#  'CROATIA': {'AB': 1911,
#   'ABA': 239,
#   'ABAB': 18,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 15,
#   'ABABCA': 1,
#   'ABABCB': 0,
#   'ABABCD': 12,
#   'ABAC': 177,
#   'ABACA': 25,
#   'ABACAC': 0,
#   'ABACAB': 5,
#   'ABACAD': 18,
#   'ABACB': 21,
#   'ABACBA': 2,
#   'ABACBC': 3,
#   'ABACBD': 12,
#   'ABACD': 101,
#   'ABACDA': 9,
#   'ABACDC': 12,
#   'ABACDB': 7,
#   'ABACDE': 56,
#   'ABC': 1307,
#   'ABCA': 109,
#   'ABCAC': 14,
#   'ABCACA': 0,
#   'ABCACB': 3,
#   'ABCACD': 9,
#   'ABCAB': 13,
#   'ABCABA': 2,
#   'ABCABC': 2,
#   'ABCABD': 8,
#   'ABCAD': 64,
#   'ABCADA': 8,
#   'ABCADC': 5,
#   'ABCADB': 6,
#   'ABCADE': 28,
#   'ABCB': 172,
#   'ABCBA': 23,
#   'ABCBAC': 1,
#   'ABCBAB': 4,
#   'ABCBAD': 16,
#   'ABCBC': 9,
#   'ABCBCA': 2,
#   'ABCBCB': 0,
#   'ABCBCD': 6,
#   'ABCBD': 113,
#   'ABCBDA': 9,
#   'ABCBDC': 15,
#   'ABCBDB': 19,
#   'ABCBDE': 51,
#   'ABCD': 745,
#   'ABCDA': 45,
#   'ABCDAC': 5,
#   'ABCDAD': 4,
#   'ABCDAB': 4,
#   'ABCDAE': 26,
#   'ABCDC': 98,
#   'ABCDCA': 11,
#   'ABCDCD': 6,
#   'ABCDCB': 10,
#   'ABCDCE': 56,
#   'ABCDB': 56,
#   'ABCDBA': 8,
#   'ABCDBC': 8,
#   'ABCDBD': 5,
#   'ABCDBE': 22,
#   'ABCDE': 370,
#   'ABCDEA': 17,
#   'ABCDEC': 28,
#   'ABCDED': 50,
#   'ABCDEB': 19,
#   'ABCDEF': 153},
#  'MACEDONIA_REPUBLIC_OF': {'AB': 1050,
#   'ABA': 145,
#   'ABAB': 26,
#   'ABABA': 6,
#   'ABABAB': 2,
#   'ABABAC': 4,
#   'ABABC': 17,
#   'ABABCA': 1,
#   'ABABCB': 0,
#   'ABABCD': 15,
#   'ABAC': 90,
#   'ABACA': 9,
#   'ABACAC': 1,
#   'ABACAB': 1,
#   'ABACAD': 4,
#   'ABACB': 6,
#   'ABACBA': 0,
#   'ABACBC': 1,
#   'ABACBD': 3,
#   'ABACD': 57,
#   'ABACDA': 3,
#   'ABACDC': 7,
#   'ABACDB': 3,
#   'ABACDE': 21,
#   'ABC': 663,
#   'ABCA': 44,
#   'ABCAC': 4,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 2,
#   'ABCAB': 5,
#   'ABCABA': 0,
#   'ABCABC': 1,
#   'ABCABD': 2,
#   'ABCAD': 24,
#   'ABCADA': 6,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 15,
#   'ABCB': 77,
#   'ABCBA': 9,
#   'ABCBAC': 1,
#   'ABCBAB': 2,
#   'ABCBAD': 6,
#   'ABCBC': 11,
#   'ABCBCA': 1,
#   'ABCBCB': 2,
#   'ABCBCD': 7,
#   'ABCBD': 44,
#   'ABCBDA': 2,
#   'ABCBDC': 3,
#   'ABCBDB': 5,
#   'ABCBDE': 24,
#   'ABCD': 359,
#   'ABCDA': 21,
#   'ABCDAC': 3,
#   'ABCDAD': 3,
#   'ABCDAB': 4,
#   'ABCDAE': 7,
#   'ABCDC': 46,
#   'ABCDCA': 1,
#   'ABCDCD': 8,
#   'ABCDCB': 5,
#   'ABCDCE': 27,
#   'ABCDB': 23,
#   'ABCDBA': 7,
#   'ABCDBC': 2,
#   'ABCDBD': 2,
#   'ABCDBE': 8,
#   'ABCDE': 162,
#   'ABCDEA': 4,
#   'ABCDEC': 9,
#   'ABCDED': 14,
#   'ABCDEB': 10,
#   'ABCDEF': 80},
#  'CZECH_REPUBLIC': {'AB': 1907,
#   'ABA': 261,
#   'ABAB': 39,
#   'ABABA': 7,
#   'ABABAB': 1,
#   'ABABAC': 5,
#   'ABABC': 24,
#   'ABABCA': 3,
#   'ABABCB': 3,
#   'ABABCD': 9,
#   'ABAC': 181,
#   'ABACA': 20,
#   'ABACAC': 4,
#   'ABACAB': 9,
#   'ABACAD': 6,
#   'ABACB': 13,
#   'ABACBA': 2,
#   'ABACBC': 1,
#   'ABACBD': 6,
#   'ABACD': 86,
#   'ABACDA': 8,
#   'ABACDC': 11,
#   'ABACDB': 2,
#   'ABACDE': 40,
#   'ABC': 1194,
#   'ABCA': 91,
#   'ABCAC': 9,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 6,
#   'ABCAB': 11,
#   'ABCABA': 2,
#   'ABCABC': 0,
#   'ABCABD': 9,
#   'ABCAD': 55,
#   'ABCADA': 4,
#   'ABCADC': 3,
#   'ABCADB': 1,
#   'ABCADE': 28,
#   'ABCB': 147,
#   'ABCBA': 25,
#   'ABCBAC': 1,
#   'ABCBAB': 3,
#   'ABCBAD': 18,
#   'ABCBC': 20,
#   'ABCBCA': 0,
#   'ABCBCB': 6,
#   'ABCBCD': 11,
#   'ABCBD': 84,
#   'ABCBDA': 5,
#   'ABCBDC': 7,
#   'ABCBDB': 9,
#   'ABCBDE': 35,
#   'ABCD': 610,
#   'ABCDA': 35,
#   'ABCDAC': 1,
#   'ABCDAD': 2,
#   'ABCDAB': 4,
#   'ABCDAE': 21,
#   'ABCDC': 74,
#   'ABCDCA': 7,
#   'ABCDCD': 7,
#   'ABCDCB': 13,
#   'ABCDCE': 37,
#   'ABCDB': 45,
#   'ABCDBA': 3,
#   'ABCDBC': 8,
#   'ABCDBD': 2,
#   'ABCDBE': 27,
#   'ABCDE': 281,
#   'ABCDEA': 20,
#   'ABCDEC': 18,
#   'ABCDED': 38,
#   'ABCDEB': 14,
#   'ABCDEF': 108},
#  'TURKEY': {'AB': 1261,
#   'ABA': 162,
#   'ABAB': 25,
#   'ABABA': 5,
#   'ABABAB': 2,
#   'ABABAC': 2,
#   'ABABC': 19,
#   'ABABCA': 2,
#   'ABABCB': 4,
#   'ABABCD': 8,
#   'ABAC': 121,
#   'ABACA': 12,
#   'ABACAC': 1,
#   'ABACAB': 0,
#   'ABACAD': 10,
#   'ABACB': 10,
#   'ABACBA': 2,
#   'ABACBC': 1,
#   'ABACBD': 5,
#   'ABACD': 68,
#   'ABACDA': 2,
#   'ABACDC': 10,
#   'ABACDB': 1,
#   'ABACDE': 42,
#   'ABC': 853,
#   'ABCA': 68,
#   'ABCAC': 8,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 8,
#   'ABCAB': 8,
#   'ABCABA': 2,
#   'ABCABC': 0,
#   'ABCABD': 6,
#   'ABCAD': 43,
#   'ABCADA': 7,
#   'ABCADC': 3,
#   'ABCADB': 3,
#   'ABCADE': 23,
#   'ABCB': 105,
#   'ABCBA': 16,
#   'ABCBAC': 4,
#   'ABCBAB': 1,
#   'ABCBAD': 11,
#   'ABCBC': 17,
#   'ABCBCA': 4,
#   'ABCBCB': 2,
#   'ABCBCD': 11,
#   'ABCBD': 64,
#   'ABCBDA': 3,
#   'ABCBDC': 2,
#   'ABCBDB': 6,
#   'ABCBDE': 35,
#   'ABCD': 479,
#   'ABCDA': 28,
#   'ABCDAC': 3,
#   'ABCDAD': 5,
#   'ABCDAB': 2,
#   'ABCDAE': 14,
#   'ABCDC': 62,
#   'ABCDCA': 2,
#   'ABCDCD': 10,
#   'ABCDCB': 15,
#   'ABCDCE': 30,
#   'ABCDB': 37,
#   'ABCDBA': 9,
#   'ABCDBC': 4,
#   'ABCDBD': 3,
#   'ABCDBE': 17,
#   'ABCDE': 232,
#   'ABCDEA': 7,
#   'ABCDEC': 19,
#   'ABCDED': 23,
#   'ABCDEB': 15,
#   'ABCDEF': 102},
#  'POLAND': {'AB': 1128,
#   'ABA': 171,
#   'ABAB': 26,
#   'ABABA': 2,
#   'ABABAB': 0,
#   'ABABAC': 0,
#   'ABABC': 12,
#   'ABABCA': 0,
#   'ABABCB': 3,
#   'ABABCD': 7,
#   'ABAC': 104,
#   'ABACA': 16,
#   'ABACAC': 3,
#   'ABACAB': 4,
#   'ABACAD': 6,
#   'ABACB': 7,
#   'ABACBA': 0,
#   'ABACBC': 1,
#   'ABACBD': 3,
#   'ABACD': 61,
#   'ABACDA': 7,
#   'ABACDC': 3,
#   'ABACDB': 4,
#   'ABACDE': 31,
#   'ABC': 683,
#   'ABCA': 51,
#   'ABCAC': 5,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 2,
#   'ABCAB': 3,
#   'ABCABA': 1,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 30,
#   'ABCADA': 2,
#   'ABCADC': 0,
#   'ABCADB': 3,
#   'ABCADE': 20,
#   'ABCB': 94,
#   'ABCBA': 13,
#   'ABCBAC': 0,
#   'ABCBAB': 1,
#   'ABCBAD': 10,
#   'ABCBC': 14,
#   'ABCBCA': 2,
#   'ABCBCB': 1,
#   'ABCBCD': 7,
#   'ABCBD': 51,
#   'ABCBDA': 9,
#   'ABCBDC': 7,
#   'ABCBDB': 8,
#   'ABCBDE': 18,
#   'ABCD': 355,
#   'ABCDA': 18,
#   'ABCDAC': 1,
#   'ABCDAD': 3,
#   'ABCDAB': 1,
#   'ABCDAE': 10,
#   'ABCDC': 50,
#   'ABCDCA': 8,
#   'ABCDCD': 7,
#   'ABCDCB': 8,
#   'ABCDCE': 20,
#   'ABCDB': 30,
#   'ABCDBA': 12,
#   'ABCDBC': 2,
#   'ABCDBD': 3,
#   'ABCDBE': 9,
#   'ABCDE': 161,
#   'ABCDEA': 6,
#   'ABCDEC': 16,
#   'ABCDED': 31,
#   'ABCDEB': 8,
#   'ABCDEF': 56},
#  'BELGIUM': {'AB': 2764,
#   'ABA': 370,
#   'ABAB': 57,
#   'ABABA': 11,
#   'ABABAB': 4,
#   'ABABAC': 6,
#   'ABABC': 39,
#   'ABABCA': 3,
#   'ABABCB': 4,
#   'ABABCD': 25,
#   'ABAC': 269,
#   'ABACA': 34,
#   'ABACAC': 8,
#   'ABACAB': 8,
#   'ABACAD': 15,
#   'ABACB': 28,
#   'ABACBA': 3,
#   'ABACBC': 6,
#   'ABACBD': 14,
#   'ABACD': 173,
#   'ABACDA': 17,
#   'ABACDC': 18,
#   'ABACDB': 6,
#   'ABACDE': 110,
#   'ABC': 1968,
#   'ABCA': 156,
#   'ABCAC': 19,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 13,
#   'ABCAB': 18,
#   'ABCABA': 2,
#   'ABCABC': 2,
#   'ABCABD': 12,
#   'ABCAD': 99,
#   'ABCADA': 9,
#   'ABCADC': 5,
#   'ABCADB': 5,
#   'ABCADE': 65,
#   'ABCB': 256,
#   'ABCBA': 50,
#   'ABCBAC': 5,
#   'ABCBAB': 8,
#   'ABCBAD': 35,
#   'ABCBC': 40,
#   'ABCBCA': 5,
#   'ABCBCB': 6,
#   'ABCBCD': 25,
#   'ABCBD': 138,
#   'ABCBDA': 17,
#   'ABCBDC': 13,
#   'ABCBDB': 18,
#   'ABCBDE': 76,
#   'ABCD': 1218,
#   'ABCDA': 76,
#   'ABCDAC': 8,
#   'ABCDAD': 12,
#   'ABCDAB': 11,
#   'ABCDAE': 40,
#   'ABCDC': 151,
#   'ABCDCA': 14,
#   'ABCDCD': 22,
#   'ABCDCB': 32,
#   'ABCDCE': 68,
#   'ABCDB': 95,
#   'ABCDBA': 20,
#   'ABCDBC': 9,
#   'ABCDBD': 8,
#   'ABCDBE': 47,
#   'ABCDE': 665,
#   'ABCDEA': 43,
#   'ABCDEC': 46,
#   'ABCDED': 83,
#   'ABCDEB': 43,
#   'ABCDEF': 298},
#  'FINLAND': {'AB': 1018,
#   'ABA': 158,
#   'ABAB': 31,
#   'ABABA': 8,
#   'ABABAB': 3,
#   'ABABAC': 5,
#   'ABABC': 16,
#   'ABABCA': 3,
#   'ABABCB': 3,
#   'ABABCD': 6,
#   'ABAC': 98,
#   'ABACA': 16,
#   'ABACAC': 2,
#   'ABACAB': 2,
#   'ABACAD': 9,
#   'ABACB': 10,
#   'ABACBA': 1,
#   'ABACBC': 3,
#   'ABACBD': 5,
#   'ABACD': 55,
#   'ABACDA': 6,
#   'ABACDC': 7,
#   'ABACDB': 0,
#   'ABACDE': 30,
#   'ABC': 641,
#   'ABCA': 54,
#   'ABCAC': 7,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 5,
#   'ABCAB': 6,
#   'ABCABA': 1,
#   'ABCABC': 0,
#   'ABCABD': 3,
#   'ABCAD': 32,
#   'ABCADA': 4,
#   'ABCADC': 1,
#   'ABCADB': 1,
#   'ABCADE': 16,
#   'ABCB': 105,
#   'ABCBA': 18,
#   'ABCBAC': 0,
#   'ABCBAB': 2,
#   'ABCBAD': 16,
#   'ABCBC': 20,
#   'ABCBCA': 2,
#   'ABCBCB': 5,
#   'ABCBCD': 7,
#   'ABCBD': 47,
#   'ABCBDA': 3,
#   'ABCBDC': 5,
#   'ABCBDB': 10,
#   'ABCBDE': 22,
#   'ABCD': 329,
#   'ABCDA': 10,
#   'ABCDAC': 1,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 6,
#   'ABCDC': 48,
#   'ABCDCA': 2,
#   'ABCDCD': 5,
#   'ABCDCB': 8,
#   'ABCDCE': 22,
#   'ABCDB': 26,
#   'ABCDBA': 2,
#   'ABCDBC': 3,
#   'ABCDBD': 3,
#   'ABCDBE': 14,
#   'ABCDE': 163,
#   'ABCDEA': 6,
#   'ABCDEC': 14,
#   'ABCDED': 23,
#   'ABCDEB': 7,
#   'ABCDEF': 72},
#  'GERMANY': {'AB': 2480,
#   'ABA': 344,
#   'ABAB': 56,
#   'ABABA': 12,
#   'ABABAB': 1,
#   'ABABAC': 9,
#   'ABABC': 34,
#   'ABABCA': 6,
#   'ABABCB': 3,
#   'ABABCD': 16,
#   'ABAC': 260,
#   'ABACA': 40,
#   'ABACAC': 8,
#   'ABACAB': 9,
#   'ABACAD': 21,
#   'ABACB': 26,
#   'ABACBA': 2,
#   'ABACBC': 2,
#   'ABACBD': 15,
#   'ABACD': 154,
#   'ABACDA': 17,
#   'ABACDC': 24,
#   'ABACDB': 10,
#   'ABACDE': 84,
#   'ABC': 1768,
#   'ABCA': 177,
#   'ABCAC': 20,
#   'ABCACA': 3,
#   'ABCACB': 4,
#   'ABCACD': 11,
#   'ABCAB': 20,
#   'ABCABA': 2,
#   'ABCABC': 5,
#   'ABCABD': 9,
#   'ABCAD': 109,
#   'ABCADA': 15,
#   'ABCADC': 8,
#   'ABCADB': 6,
#   'ABCADE': 60,
#   'ABCB': 237,
#   'ABCBA': 42,
#   'ABCBAC': 2,
#   'ABCBAB': 13,
#   'ABCBAD': 25,
#   'ABCBC': 36,
#   'ABCBCA': 2,
#   'ABCBCB': 11,
#   'ABCBCD': 18,
#   'ABCBD': 143,
#   'ABCBDA': 15,
#   'ABCBDC': 13,
#   'ABCBDB': 22,
#   'ABCBDE': 72,
#   'ABCD': 1054,
#   'ABCDA': 73,
#   'ABCDAC': 4,
#   'ABCDAD': 3,
#   'ABCDAB': 8,
#   'ABCDAE': 50,
#   'ABCDC': 144,
#   'ABCDCA': 18,
#   'ABCDCD': 20,
#   'ABCDCB': 26,
#   'ABCDCE': 71,
#   'ABCDB': 105,
#   'ABCDBA': 15,
#   'ABCDBC': 9,
#   'ABCDBD': 15,
#   'ABCDBE': 55,
#   'ABCDE': 541,
#   'ABCDEA': 26,
#   'ABCDEC': 60,
#   'ABCDED': 79,
#   'ABCDEB': 35,
#   'ABCDEF': 230},
#  'UKRAINE': {'AB': 2580,
#   'ABA': 373,
#   'ABAB': 53,
#   'ABABA': 12,
#   'ABABAB': 3,
#   'ABABAC': 7,
#   'ABABC': 30,
#   'ABABCA': 2,
#   'ABABCB': 7,
#   'ABABCD': 18,
#   'ABAC': 266,
#   'ABACA': 41,
#   'ABACAC': 5,
#   'ABACAB': 7,
#   'ABACAD': 28,
#   'ABACB': 15,
#   'ABACBA': 2,
#   'ABACBC': 2,
#   'ABACBD': 11,
#   'ABACD': 172,
#   'ABACDA': 13,
#   'ABACDC': 25,
#   'ABACDB': 6,
#   'ABACDE': 97,
#   'ABC': 1805,
#   'ABCA': 164,
#   'ABCAC': 20,
#   'ABCACA': 1,
#   'ABCACB': 3,
#   'ABCACD': 14,
#   'ABCAB': 27,
#   'ABCABA': 5,
#   'ABCABC': 5,
#   'ABCABD': 14,
#   'ABCAD': 98,
#   'ABCADA': 18,
#   'ABCADC': 7,
#   'ABCADB': 7,
#   'ABCADE': 45,
#   'ABCB': 254,
#   'ABCBA': 47,
#   'ABCBAC': 2,
#   'ABCBAB': 8,
#   'ABCBAD': 35,
#   'ABCBC': 28,
#   'ABCBCA': 2,
#   'ABCBCB': 4,
#   'ABCBCD': 16,
#   'ABCBD': 148,
#   'ABCBDA': 13,
#   'ABCBDC': 8,
#   'ABCBDB': 24,
#   'ABCBDE': 86,
#   'ABCD': 1068,
#   'ABCDA': 58,
#   'ABCDAC': 6,
#   'ABCDAD': 5,
#   'ABCDAB': 9,
#   'ABCDAE': 30,
#   'ABCDC': 146,
#   'ABCDCA': 13,
#   'ABCDCD': 21,
#   'ABCDCB': 32,
#   'ABCDCE': 60,
#   'ABCDB': 100,
#   'ABCDBA': 15,
#   'ABCDBC': 16,
#   'ABCDBD': 12,
#   'ABCDBE': 44,
#   'ABCDE': 551,
#   'ABCDEA': 29,
#   'ABCDEC': 56,
#   'ABCDED': 72,
#   'ABCDEB': 27,
#   'ABCDEF': 265},
#  'AUSTRIA': {'AB': 2010,
#   'ABA': 257,
#   'ABAB': 35,
#   'ABABA': 2,
#   'ABABAB': 0,
#   'ABABAC': 2,
#   'ABABC': 26,
#   'ABABCA': 3,
#   'ABABCB': 5,
#   'ABABCD': 14,
#   'ABAC': 182,
#   'ABACA': 22,
#   'ABACAC': 2,
#   'ABACAB': 2,
#   'ABACAD': 14,
#   'ABACB': 16,
#   'ABACBA': 1,
#   'ABACBC': 0,
#   'ABACBD': 14,
#   'ABACD': 100,
#   'ABACDA': 5,
#   'ABACDC': 11,
#   'ABACDB': 5,
#   'ABACDE': 61,
#   'ABC': 1351,
#   'ABCA': 99,
#   'ABCAC': 6,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 5,
#   'ABCAB': 12,
#   'ABCABA': 1,
#   'ABCABC': 2,
#   'ABCABD': 8,
#   'ABCAD': 65,
#   'ABCADA': 5,
#   'ABCADC': 3,
#   'ABCADB': 5,
#   'ABCADE': 38,
#   'ABCB': 163,
#   'ABCBA': 24,
#   'ABCBAC': 2,
#   'ABCBAB': 1,
#   'ABCBAD': 17,
#   'ABCBC': 20,
#   'ABCBCA': 2,
#   'ABCBCB': 1,
#   'ABCBCD': 14,
#   'ABCBD': 96,
#   'ABCBDA': 7,
#   'ABCBDC': 9,
#   'ABCBDB': 10,
#   'ABCBDE': 49,
#   'ABCD': 769,
#   'ABCDA': 42,
#   'ABCDAC': 5,
#   'ABCDAD': 2,
#   'ABCDAB': 3,
#   'ABCDAE': 22,
#   'ABCDC': 89,
#   'ABCDCA': 4,
#   'ABCDCD': 10,
#   'ABCDCB': 18,
#   'ABCDCE': 46,
#   'ABCDB': 54,
#   'ABCDBA': 6,
#   'ABCDBC': 7,
#   'ABCDBD': 5,
#   'ABCDBE': 26,
#   'ABCDE': 380,
#   'ABCDEA': 16,
#   'ABCDEC': 24,
#   'ABCDED': 42,
#   'ABCDEB': 22,
#   'ABCDEF': 152},
#  'NETHERLANDS': {'AB': 2082,
#   'ABA': 327,
#   'ABAB': 54,
#   'ABABA': 15,
#   'ABABAB': 4,
#   'ABABAC': 11,
#   'ABABC': 33,
#   'ABABCA': 3,
#   'ABABCB': 7,
#   'ABABCD': 16,
#   'ABAC': 233,
#   'ABACA': 39,
#   'ABACAC': 7,
#   'ABACAB': 9,
#   'ABACAD': 20,
#   'ABACB': 23,
#   'ABACBA': 4,
#   'ABACBC': 3,
#   'ABACBD': 14,
#   'ABACD': 120,
#   'ABACDA': 15,
#   'ABACDC': 17,
#   'ABACDB': 8,
#   'ABACDE': 63,
#   'ABC': 1356,
#   'ABCA': 137,
#   'ABCAC': 19,
#   'ABCACA': 5,
#   'ABCACB': 3,
#   'ABCACD': 11,
#   'ABCAB': 30,
#   'ABCABA': 4,
#   'ABCABC': 9,
#   'ABCABD': 13,
#   'ABCAD': 73,
#   'ABCADA': 10,
#   'ABCADC': 6,
#   'ABCADB': 4,
#   'ABCADE': 34,
#   'ABCB': 207,
#   'ABCBA': 45,
#   'ABCBAC': 4,
#   'ABCBAB': 11,
#   'ABCBAD': 23,
#   'ABCBC': 27,
#   'ABCBCA': 1,
#   'ABCBCB': 8,
#   'ABCBCD': 14,
#   'ABCBD': 113,
#   'ABCBDA': 10,
#   'ABCBDC': 11,
#   'ABCBDB': 17,
#   'ABCBDE': 51,
#   'ABCD': 711,
#   'ABCDA': 38,
#   'ABCDAC': 4,
#   'ABCDAD': 5,
#   'ABCDAB': 2,
#   'ABCDAE': 20,
#   'ABCDC': 105,
#   'ABCDCA': 6,
#   'ABCDCD': 11,
#   'ABCDCB': 26,
#   'ABCDCE': 50,
#   'ABCDB': 63,
#   'ABCDBA': 10,
#   'ABCDBC': 12,
#   'ABCDBD': 11,
#   'ABCDBE': 24,
#   'ABCDE': 329,
#   'ABCDEA': 16,
#   'ABCDEC': 26,
#   'ABCDED': 49,
#   'ABCDEB': 18,
#   'ABCDEF': 129},
#  'HUNGARY': {'AB': 773,
#   'ABA': 122,
#   'ABAB': 20,
#   'ABABA': 2,
#   'ABABAB': 0,
#   'ABABAC': 2,
#   'ABABC': 15,
#   'ABABCA': 1,
#   'ABABCB': 2,
#   'ABABCD': 5,
#   'ABAC': 75,
#   'ABACA': 14,
#   'ABACAC': 3,
#   'ABACAB': 3,
#   'ABACAD': 6,
#   'ABACB': 7,
#   'ABACBA': 1,
#   'ABACBC': 0,
#   'ABACBD': 6,
#   'ABACD': 29,
#   'ABACDA': 0,
#   'ABACDC': 6,
#   'ABACDB': 0,
#   'ABACDE': 11,
#   'ABC': 446,
#   'ABCA': 35,
#   'ABCAC': 4,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 2,
#   'ABCAB': 6,
#   'ABCABA': 0,
#   'ABCABC': 1,
#   'ABCABD': 5,
#   'ABCAD': 19,
#   'ABCADA': 1,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 5,
#   'ABCB': 65,
#   'ABCBA': 11,
#   'ABCBAC': 2,
#   'ABCBAB': 4,
#   'ABCBAD': 4,
#   'ABCBC': 10,
#   'ABCBCA': 0,
#   'ABCBCB': 1,
#   'ABCBCD': 7,
#   'ABCBD': 29,
#   'ABCBDA': 3,
#   'ABCBDC': 2,
#   'ABCBDB': 4,
#   'ABCBDE': 11,
#   'ABCD': 197,
#   'ABCDA': 8,
#   'ABCDAC': 1,
#   'ABCDAD': 0,
#   'ABCDAB': 3,
#   'ABCDAE': 4,
#   'ABCDC': 28,
#   'ABCDCA': 2,
#   'ABCDCD': 4,
#   'ABCDCB': 4,
#   'ABCDCE': 10,
#   'ABCDB': 10,
#   'ABCDBA': 0,
#   'ABCDBC': 1,
#   'ABCDBD': 1,
#   'ABCDBE': 4,
#   'ABCDE': 79,
#   'ABCDEA': 2,
#   'ABCDEC': 5,
#   'ABCDED': 11,
#   'ABCDEB': 3,
#   'ABCDEF': 35},
#  'SWEDEN': {'AB': 1338,
#   'ABA': 158,
#   'ABAB': 18,
#   'ABABA': 2,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 10,
#   'ABABCA': 0,
#   'ABABCB': 2,
#   'ABABCD': 6,
#   'ABAC': 109,
#   'ABACA': 14,
#   'ABACAC': 1,
#   'ABACAB': 4,
#   'ABACAD': 9,
#   'ABACB': 5,
#   'ABACBA': 0,
#   'ABACBC': 2,
#   'ABACBD': 3,
#   'ABACD': 66,
#   'ABACDA': 3,
#   'ABACDC': 8,
#   'ABACDB': 1,
#   'ABACDE': 36,
#   'ABC': 877,
#   'ABCA': 58,
#   'ABCAC': 5,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 3,
#   'ABCAB': 8,
#   'ABCABA': 0,
#   'ABCABC': 1,
#   'ABCABD': 3,
#   'ABCAD': 36,
#   'ABCADA': 7,
#   'ABCADC': 4,
#   'ABCADB': 3,
#   'ABCADE': 17,
#   'ABCB': 103,
#   'ABCBA': 15,
#   'ABCBAC': 2,
#   'ABCBAB': 2,
#   'ABCBAD': 10,
#   'ABCBC': 10,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 6,
#   'ABCBD': 65,
#   'ABCBDA': 7,
#   'ABCBDC': 1,
#   'ABCBDB': 7,
#   'ABCBDE': 37,
#   'ABCD': 505,
#   'ABCDA': 33,
#   'ABCDAC': 0,
#   'ABCDAD': 3,
#   'ABCDAB': 4,
#   'ABCDAE': 22,
#   'ABCDC': 63,
#   'ABCDCA': 5,
#   'ABCDCD': 6,
#   'ABCDCB': 10,
#   'ABCDCE': 31,
#   'ABCDB': 30,
#   'ABCDBA': 3,
#   'ABCDBC': 6,
#   'ABCDBD': 3,
#   'ABCDBE': 16,
#   'ABCDE': 264,
#   'ABCDEA': 20,
#   'ABCDEC': 16,
#   'ABCDED': 38,
#   'ABCDEB': 14,
#   'ABCDEF': 114},
#  'SWITZERLAND': {'AB': 2301,
#   'ABA': 294,
#   'ABAB': 46,
#   'ABABA': 11,
#   'ABABAB': 1,
#   'ABABAC': 9,
#   'ABABC': 29,
#   'ABABCA': 2,
#   'ABABCB': 3,
#   'ABABCD': 18,
#   'ABAC': 207,
#   'ABACA': 24,
#   'ABACAC': 4,
#   'ABACAB': 8,
#   'ABACAD': 11,
#   'ABACB': 20,
#   'ABACBA': 3,
#   'ABACBC': 1,
#   'ABACBD': 12,
#   'ABACD': 117,
#   'ABACDA': 5,
#   'ABACDC': 16,
#   'ABACDB': 10,
#   'ABACDE': 59,
#   'ABC': 1559,
#   'ABCA': 116,
#   'ABCAC': 15,
#   'ABCACA': 2,
#   'ABCACB': 2,
#   'ABCACD': 9,
#   'ABCAB': 17,
#   'ABCABA': 2,
#   'ABCABC': 7,
#   'ABCABD': 5,
#   'ABCAD': 69,
#   'ABCADA': 6,
#   'ABCADC': 2,
#   'ABCADB': 4,
#   'ABCADE': 39,
#   'ABCB': 196,
#   'ABCBA': 34,
#   'ABCBAC': 3,
#   'ABCBAB': 5,
#   'ABCBAD': 24,
#   'ABCBC': 28,
#   'ABCBCA': 4,
#   'ABCBCB': 10,
#   'ABCBCD': 10,
#   'ABCBD': 109,
#   'ABCBDA': 8,
#   'ABCBDC': 11,
#   'ABCBDB': 11,
#   'ABCBDE': 54,
#   'ABCD': 899,
#   'ABCDA': 63,
#   'ABCDAC': 5,
#   'ABCDAD': 14,
#   'ABCDAB': 10,
#   'ABCDAE': 26,
#   'ABCDC': 118,
#   'ABCDCA': 3,
#   'ABCDCD': 16,
#   'ABCDCB': 19,
#   'ABCDCE': 63,
#   'ABCDB': 62,
#   'ABCDBA': 12,
#   'ABCDBC': 6,
#   'ABCDBD': 10,
#   'ABCDBE': 27,
#   'ABCDE': 438,
#   'ABCDEA': 22,
#   'ABCDEC': 31,
#   'ABCDED': 49,
#   'ABCDEB': 24,
#   'ABCDEF': 201},
#  'DENMARK': {'AB': 2819,
#   'ABA': 362,
#   'ABAB': 40,
#   'ABABA': 5,
#   'ABABAB': 0,
#   'ABABAC': 5,
#   'ABABC': 30,
#   'ABABCA': 1,
#   'ABABCB': 3,
#   'ABABCD': 19,
#   'ABAC': 253,
#   'ABACA': 26,
#   'ABACAC': 3,
#   'ABACAB': 8,
#   'ABACAD': 11,
#   'ABACB': 17,
#   'ABACBA': 5,
#   'ABACBC': 1,
#   'ABACBD': 10,
#   'ABACD': 155,
#   'ABACDA': 8,
#   'ABACDC': 20,
#   'ABACDB': 7,
#   'ABACDE': 88,
#   'ABC': 1877,
#   'ABCA': 165,
#   'ABCAC': 24,
#   'ABCACA': 3,
#   'ABCACB': 2,
#   'ABCACD': 14,
#   'ABCAB': 23,
#   'ABCABA': 4,
#   'ABCABC': 3,
#   'ABCABD': 12,
#   'ABCAD': 94,
#   'ABCADA': 11,
#   'ABCADC': 10,
#   'ABCADB': 2,
#   'ABCADE': 52,
#   'ABCB': 231,
#   'ABCBA': 38,
#   'ABCBAC': 2,
#   'ABCBAB': 5,
#   'ABCBAD': 25,
#   'ABCBC': 23,
#   'ABCBCA': 2,
#   'ABCBCB': 4,
#   'ABCBCD': 14,
#   'ABCBD': 125,
#   'ABCBDA': 11,
#   'ABCBDC': 8,
#   'ABCBDB': 12,
#   'ABCBDE': 66,
#   'ABCD': 1051,
#   'ABCDA': 48,
#   'ABCDAC': 5,
#   'ABCDAD': 9,
#   'ABCDAB': 4,
#   'ABCDAE': 23,
#   'ABCDC': 135,
#   'ABCDCA': 13,
#   'ABCDCD': 13,
#   'ABCDCB': 20,
#   'ABCDCE': 65,
#   'ABCDB': 99,
#   'ABCDBA': 14,
#   'ABCDBC': 13,
#   'ABCDBD': 17,
#   'ABCDBE': 42,
#   'ABCDE': 524,
#   'ABCDEA': 24,
#   'ABCDEC': 49,
#   'ABCDED': 70,
#   'ABCDEB': 24,
#   'ABCDEF': 230},
#  'FRANCE': {'AB': 2225,
#   'ABA': 327,
#   'ABAB': 53,
#   'ABABA': 5,
#   'ABABAB': 0,
#   'ABABAC': 3,
#   'ABABC': 39,
#   'ABABCA': 2,
#   'ABABCB': 7,
#   'ABABCD': 23,
#   'ABAC': 224,
#   'ABACA': 29,
#   'ABACAC': 2,
#   'ABACAB': 5,
#   'ABACAD': 18,
#   'ABACB': 20,
#   'ABACBA': 2,
#   'ABACBC': 1,
#   'ABACBD': 13,
#   'ABACD': 142,
#   'ABACDA': 9,
#   'ABACDC': 17,
#   'ABACDB': 3,
#   'ABACDE': 89,
#   'ABC': 1561,
#   'ABCA': 142,
#   'ABCAC': 17,
#   'ABCACA': 4,
#   'ABCACB': 3,
#   'ABCACD': 5,
#   'ABCAB': 20,
#   'ABCABA': 3,
#   'ABCABC': 5,
#   'ABCABD': 8,
#   'ABCAD': 85,
#   'ABCADA': 10,
#   'ABCADC': 6,
#   'ABCADB': 5,
#   'ABCADE': 54,
#   'ABCB': 224,
#   'ABCBA': 40,
#   'ABCBAC': 4,
#   'ABCBAB': 5,
#   'ABCBAD': 30,
#   'ABCBC': 39,
#   'ABCBCA': 5,
#   'ABCBCB': 5,
#   'ABCBCD': 24,
#   'ABCBD': 113,
#   'ABCBDA': 9,
#   'ABCBDC': 11,
#   'ABCBDB': 16,
#   'ABCBDE': 57,
#   'ABCD': 943,
#   'ABCDA': 50,
#   'ABCDAC': 3,
#   'ABCDAD': 6,
#   'ABCDAB': 5,
#   'ABCDAE': 33,
#   'ABCDC': 140,
#   'ABCDCA': 14,
#   'ABCDCD': 27,
#   'ABCDCB': 29,
#   'ABCDCE': 54,
#   'ABCDB': 80,
#   'ABCDBA': 16,
#   'ABCDBC': 10,
#   'ABCDBD': 9,
#   'ABCDBE': 36,
#   'ABCDE': 522,
#   'ABCDEA': 24,
#   'ABCDEC': 51,
#   'ABCDED': 87,
#   'ABCDEB': 33,
#   'ABCDEF': 239},
#  'RUSSIA': {'AB': 1098,
#   'ABA': 129,
#   'ABAB': 18,
#   'ABABA': 3,
#   'ABABAB': 1,
#   'ABABAC': 1,
#   'ABABC': 11,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 6,
#   'ABAC': 86,
#   'ABACA': 12,
#   'ABACAC': 1,
#   'ABACAB': 2,
#   'ABACAD': 7,
#   'ABACB': 4,
#   'ABACBA': 1,
#   'ABACBC': 0,
#   'ABACBD': 2,
#   'ABACD': 47,
#   'ABACDA': 2,
#   'ABACDC': 3,
#   'ABACDB': 2,
#   'ABACDE': 31,
#   'ABC': 705,
#   'ABCA': 40,
#   'ABCAC': 3,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 1,
#   'ABCAB': 4,
#   'ABCABA': 1,
#   'ABCABC': 1,
#   'ABCABD': 2,
#   'ABCAD': 26,
#   'ABCADA': 2,
#   'ABCADC': 2,
#   'ABCADB': 1,
#   'ABCADE': 16,
#   'ABCB': 84,
#   'ABCBA': 14,
#   'ABCBAC': 2,
#   'ABCBAB': 1,
#   'ABCBAD': 10,
#   'ABCBC': 9,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 6,
#   'ABCBD': 47,
#   'ABCBDA': 2,
#   'ABCBDC': 2,
#   'ABCBDB': 9,
#   'ABCBDE': 25,
#   'ABCD': 381,
#   'ABCDA': 12,
#   'ABCDAC': 1,
#   'ABCDAD': 4,
#   'ABCDAB': 2,
#   'ABCDAE': 3,
#   'ABCDC': 53,
#   'ABCDCA': 5,
#   'ABCDCD': 4,
#   'ABCDCB': 10,
#   'ABCDCE': 24,
#   'ABCDB': 24,
#   'ABCDBA': 5,
#   'ABCDBC': 2,
#   'ABCDBD': 0,
#   'ABCDBE': 12,
#   'ABCDE': 176,
#   'ABCDEA': 3,
#   'ABCDEC': 11,
#   'ABCDED': 27,
#   'ABCDEB': 4,
#   'ABCDEF': 75}}

# %%
result
# Out:
# {'PORTUGAL': {'AB': 254,
#   'ABA': 49,
#   'ABC': 197,
#   'ABAB': 4,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 0,
#   'ABABC': 3,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABABCDA': 0,
#   'ABABCDC': 1,
#   'ABABCDB': 0,
#   'ABAC': 33,
#   'ABACA': 6,
#   'ABACAC': 0,
#   'ABACAB': 1,
#   'ABACAD': 4,
#   'ABACB': 1,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 1,
#   'ABACD': 20,
#   'ABACDA': 1,
#   'ABACDC': 1,
#   'ABACDB': 1,
#   'ABACDE': 14,
#   'ABCA': 15,
#   'ABCAC': 4,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 2,
#   'ABCAB': 3,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 2,
#   'ABCAD': 6,
#   'ABCADA': 0,
#   'ABCADC': 1,
#   'ABCADB': 0,
#   'ABCADE': 4,
#   'ABCB': 31,
#   'ABCBA': 2,
#   'ABCBAC': 0,
#   'ABCBAB': 1,
#   'ABCBAD': 1,
#   'ABCBC': 6,
#   'ABCBCA': 0,
#   'ABCBCB': 2,
#   'ABCBCD': 4,
#   'ABCBD': 21,
#   'ABCBDA': 0,
#   'ABCBDC': 1,
#   'ABCBDB': 6,
#   'ABCBDE': 8,
#   'ABCD': 122,
#   'ABCDA': 4,
#   'ABCDAC': 1,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 2,
#   'ABCDC': 18,
#   'ABCDCA': 2,
#   'ABCDCD': 2,
#   'ABCDCB': 3,
#   'ABCDCE': 11,
#   'ABCDB': 4,
#   'ABCDBA': 1,
#   'ABCDBC': 0,
#   'ABCDBD': 0,
#   'ABCDBE': 3,
#   'ABCDE': 70,
#   'ABCDEA': 6,
#   'ABCDEC': 5,
#   'ABCDED': 6,
#   'ABCDEB': 7,
#   'ABCDEF': 31},
#  'SCOTLAND': {'AB': 187,
#   'ABA': 23,
#   'ABC': 138,
#   'ABAB': 4,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 2,
#   'ABABCA': 1,
#   'ABABCB': 0,
#   'ABABCD': 1,
#   'ABAC': 17,
#   'ABACA': 1,
#   'ABACAC': 1,
#   'ABACAB': 0,
#   'ABACAD': 0,
#   'ABACB': 0,
#   'ABACD': 5,
#   'ABACDA': 0,
#   'ABACDC': 0,
#   'ABACDB': 0,
#   'ABACDE': 3,
#   'ABCA': 5,
#   'ABCAC': 0,
#   'ABCAB': 2,
#   'ABCABA': 2,
#   'ABCABC': 0,
#   'ABCABD': 0,
#   'ABCAD': 1,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 0,
#   'ABCB': 12,
#   'ABCBA': 1,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 0,
#   'ABCBC': 1,
#   'ABCBCA': 0,
#   'ABCBCB': 1,
#   'ABCBCD': 0,
#   'ABCBD': 7,
#   'ABCBDA': 0,
#   'ABCBDC': 0,
#   'ABCBDB': 0,
#   'ABCBDE': 4,
#   'ABCD': 78,
#   'ABCDA': 5,
#   'ABCDAC': 0,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 2,
#   'ABCDC': 9,
#   'ABCDCA': 1,
#   'ABCDCD': 0,
#   'ABCDCB': 2,
#   'ABCDCE': 3,
#   'ABCDB': 7,
#   'ABCDBA': 1,
#   'ABCDBC': 0,
#   'ABCDBD': 0,
#   'ABCDBE': 5,
#   'ABCDE': 35,
#   'ABCDEA': 6,
#   'ABCDEC': 4,
#   'ABCDED': 3,
#   'ABCDEB': 3,
#   'ABCDEF': 12},
#  'ITALY': {'AB': 512,
#   'ABA': 90,
#   'ABC': 395,
#   'ABAB': 17,
#   'ABABA': 4,
#   'ABABAB': 1,
#   'ABABAC': 2,
#   'ABABC': 8,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 5,
#   'ABAC': 55,
#   'ABACA': 4,
#   'ABACAC': 1,
#   'ABACAB': 1,
#   'ABACAD': 2,
#   'ABACB': 3,
#   'ABACBA': 1,
#   'ABACBC': 1,
#   'ABACBD': 1,
#   'ABACD': 30,
#   'ABACDA': 2,
#   'ABACDC': 4,
#   'ABACDB': 2,
#   'ABACDE': 17,
#   'ABCA': 30,
#   'ABCAC': 5,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 4,
#   'ABCAB': 2,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 20,
#   'ABCADA': 3,
#   'ABCADC': 2,
#   'ABCADB': 2,
#   'ABCADE': 12,
#   'ABCB': 45,
#   'ABCBA': 4,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 4,
#   'ABCBC': 8,
#   'ABCBCA': 0,
#   'ABCBCB': 1,
#   'ABCBCD': 7,
#   'ABCBD': 24,
#   'ABCBDA': 1,
#   'ABCBDC': 3,
#   'ABCBDB': 3,
#   'ABCBDE': 12,
#   'ABCD': 252,
#   'ABCDA': 17,
#   'ABCDAC': 0,
#   'ABCDAD': 4,
#   'ABCDAB': 2,
#   'ABCDAE': 9,
#   'ABCDC': 40,
#   'ABCDCA': 4,
#   'ABCDCD': 10,
#   'ABCDCB': 6,
#   'ABCDCE': 17,
#   'ABCDB': 18,
#   'ABCDBA': 2,
#   'ABCDBC': 3,
#   'ABCDBD': 4,
#   'ABCDBE': 6,
#   'ABCDE': 123,
#   'ABCDEA': 6,
#   'ABCDEC': 12,
#   'ABCDED': 24,
#   'ABCDEB': 5,
#   'ABCDEF': 49},
#  'ENGLAND': {'AB': 400,
#   'ABA': 70,
#   'ABC': 284,
#   'ABAB': 6,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 5,
#   'ABABCA': 0,
#   'ABABCB': 1,
#   'ABABCD': 4,
#   'ABAC': 54,
#   'ABACA': 3,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 2,
#   'ABACB': 3,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 1,
#   'ABACD': 30,
#   'ABACDA': 3,
#   'ABACDC': 4,
#   'ABACDB': 1,
#   'ABACDE': 17,
#   'ABCA': 16,
#   'ABCAC': 2,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 10,
#   'ABCADA': 2,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 4,
#   'ABCB': 37,
#   'ABCBA': 5,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 5,
#   'ABCBC': 5,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 5,
#   'ABCBD': 20,
#   'ABCBDA': 2,
#   'ABCBDC': 1,
#   'ABCBDB': 3,
#   'ABCBDE': 11,
#   'ABCD': 172,
#   'ABCDA': 13,
#   'ABCDAC': 0,
#   'ABCDAD': 1,
#   'ABCDAB': 3,
#   'ABCDAE': 8,
#   'ABCDC': 28,
#   'ABCDCA': 4,
#   'ABCDCD': 5,
#   'ABCDCB': 5,
#   'ABCDCE': 9,
#   'ABCDB': 11,
#   'ABCDBA': 1,
#   'ABCDBC': 3,
#   'ABCDBD': 2,
#   'ABCDBE': 4,
#   'ABCDE': 81,
#   'ABCDEA': 6,
#   'ABCDEC': 9,
#   'ABCDED': 16,
#   'ABCDEB': 7,
#   'ABCDEF': 32},
#  'SPAIN': {'AB': 499,
#   'ABA': 71,
#   'ABC': 404,
#   'ABAB': 20,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 16,
#   'ABABCA': 3,
#   'ABABCB': 4,
#   'ABABCD': 9,
#   'ABAC': 44,
#   'ABACA': 5,
#   'ABACAC': 0,
#   'ABACAB': 2,
#   'ABACAD': 2,
#   'ABACB': 6,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 5,
#   'ABACD': 20,
#   'ABACDA': 0,
#   'ABACDC': 1,
#   'ABACDB': 1,
#   'ABACDE': 11,
#   'ABCA': 39,
#   'ABCAC': 4,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 4,
#   'ABCAB': 2,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 2,
#   'ABCAD': 28,
#   'ABCADA': 0,
#   'ABCADC': 3,
#   'ABCADB': 2,
#   'ABCADE': 18,
#   'ABCB': 55,
#   'ABCBA': 7,
#   'ABCBAC': 0,
#   'ABCBAB': 5,
#   'ABCBAD': 2,
#   'ABCBC': 5,
#   'ABCBCA': 1,
#   'ABCBCB': 1,
#   'ABCBCD': 3,
#   'ABCBD': 39,
#   'ABCBDA': 3,
#   'ABCBDC': 1,
#   'ABCBDB': 6,
#   'ABCBDE': 19,
#   'ABCD': 255,
#   'ABCDA': 11,
#   'ABCDAC': 1,
#   'ABCDAD': 2,
#   'ABCDAB': 2,
#   'ABCDAE': 4,
#   'ABCDC': 38,
#   'ABCDCA': 4,
#   'ABCDCD': 8,
#   'ABCDCB': 8,
#   'ABCDCE': 16,
#   'ABCDB': 26,
#   'ABCDBA': 3,
#   'ABCDBC': 5,
#   'ABCDBD': 3,
#   'ABCDBE': 12,
#   'ABCDE': 148,
#   'ABCDEA': 10,
#   'ABCDEC': 14,
#   'ABCDED': 30,
#   'ABCDEB': 5,
#   'ABCDEF': 66},
#  'SLOVAKIA': {'AB': 166,
#   'ABA': 25,
#   'ABC': 127,
#   'ABAB': 3,
#   'ABABA': 0,
#   'ABABC': 3,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 19,
#   'ABACA': 2,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 0,
#   'ABACB': 0,
#   'ABACD': 15,
#   'ABACDA': 2,
#   'ABACDC': 3,
#   'ABACDB': 1,
#   'ABACDE': 6,
#   'ABCA': 4,
#   'ABCAC': 0,
#   'ABCAB': 0,
#   'ABCAD': 3,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 3,
#   'ABCB': 16,
#   'ABCBA': 2,
#   'ABCBAC': 0,
#   'ABCBAB': 1,
#   'ABCBAD': 1,
#   'ABCBC': 1,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 1,
#   'ABCBD': 12,
#   'ABCBDA': 1,
#   'ABCBDC': 1,
#   'ABCBDB': 0,
#   'ABCBDE': 7,
#   'ABCD': 73,
#   'ABCDA': 3,
#   'ABCDAC': 0,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 1,
#   'ABCDC': 18,
#   'ABCDCA': 1,
#   'ABCDCD': 1,
#   'ABCDCB': 3,
#   'ABCDCE': 11,
#   'ABCDB': 5,
#   'ABCDBA': 1,
#   'ABCDBC': 1,
#   'ABCDBD': 0,
#   'ABCDBE': 3,
#   'ABCDE': 38,
#   'ABCDEA': 2,
#   'ABCDEC': 4,
#   'ABCDED': 3,
#   'ABCDEB': 5,
#   'ABCDEF': 16},
#  'WALES': {'AB': 195,
#   'ABA': 25,
#   'ABC': 153,
#   'ABAB': 3,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 0,
#   'ABABC': 2,
#   'ABABCA': 1,
#   'ABABCB': 0,
#   'ABABCD': 1,
#   'ABAC': 18,
#   'ABACA': 0,
#   'ABACB': 0,
#   'ABACD': 14,
#   'ABACDA': 1,
#   'ABACDC': 3,
#   'ABACDB': 0,
#   'ABACDE': 7,
#   'ABCA': 7,
#   'ABCAC': 0,
#   'ABCAB': 0,
#   'ABCAD': 5,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 1,
#   'ABCB': 16,
#   'ABCBA': 3,
#   'ABCBAC': 1,
#   'ABCBAB': 1,
#   'ABCBAD': 1,
#   'ABCBC': 0,
#   'ABCBD': 8,
#   'ABCBDA': 0,
#   'ABCBDC': 0,
#   'ABCBDB': 0,
#   'ABCBDE': 4,
#   'ABCD': 89,
#   'ABCDA': 3,
#   'ABCDAC': 0,
#   'ABCDAD': 0,
#   'ABCDAB': 0,
#   'ABCDAE': 1,
#   'ABCDC': 10,
#   'ABCDCA': 1,
#   'ABCDCD': 2,
#   'ABCDCB': 0,
#   'ABCDCE': 4,
#   'ABCDB': 8,
#   'ABCDBA': 1,
#   'ABCDBC': 1,
#   'ABCDBD': 1,
#   'ABCDBE': 4,
#   'ABCDE': 45,
#   'ABCDEA': 0,
#   'ABCDEC': 4,
#   'ABCDED': 7,
#   'ABCDEB': 2,
#   'ABCDEF': 19},
#  'CROATIA': {'AB': 276,
#   'ABA': 38,
#   'ABC': 220,
#   'ABAB': 7,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 5,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 5,
#   'ABAC': 19,
#   'ABACA': 1,
#   'ABACAC': 0,
#   'ABACAB': 1,
#   'ABACAD': 0,
#   'ABACB': 4,
#   'ABACBA': 2,
#   'ABACBC': 0,
#   'ABACBD': 2,
#   'ABACD': 8,
#   'ABACDA': 2,
#   'ABACDC': 0,
#   'ABACDB': 0,
#   'ABACDE': 4,
#   'ABCA': 13,
#   'ABCAC': 1,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 11,
#   'ABCADA': 1,
#   'ABCADC': 1,
#   'ABCADB': 0,
#   'ABCADE': 7,
#   'ABCB': 27,
#   'ABCBA': 3,
#   'ABCBAC': 0,
#   'ABCBAB': 1,
#   'ABCBAD': 2,
#   'ABCBC': 2,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 2,
#   'ABCBD': 17,
#   'ABCBDA': 1,
#   'ABCBDC': 2,
#   'ABCBDB': 2,
#   'ABCBDE': 9,
#   'ABCD': 136,
#   'ABCDA': 8,
#   'ABCDAC': 0,
#   'ABCDAD': 0,
#   'ABCDAB': 0,
#   'ABCDAE': 7,
#   'ABCDC': 19,
#   'ABCDCA': 3,
#   'ABCDCD': 1,
#   'ABCDCB': 1,
#   'ABCDCE': 12,
#   'ABCDB': 8,
#   'ABCDBA': 0,
#   'ABCDBC': 2,
#   'ABCDBD': 0,
#   'ABCDBE': 5,
#   'ABCDE': 72,
#   'ABCDEA': 3,
#   'ABCDEC': 2,
#   'ABCDED': 12,
#   'ABCDEB': 4,
#   'ABCDEF': 37},
#  'MACEDONIA_REPUBLIC_OF': {'AB': 186,
#   'ABA': 35,
#   'ABC': 140,
#   'ABAB': 5,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 2,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 19,
#   'ABACA': 2,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 1,
#   'ABACB': 1,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 0,
#   'ABACD': 9,
#   'ABACDA': 0,
#   'ABACDC': 2,
#   'ABACDB': 0,
#   'ABACDE': 4,
#   'ABCA': 9,
#   'ABCAC': 1,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 0,
#   'ABCAB': 2,
#   'ABCABA': 0,
#   'ABCABC': 1,
#   'ABCABD': 0,
#   'ABCAD': 3,
#   'ABCADA': 2,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 1,
#   'ABCB': 18,
#   'ABCBA': 2,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 2,
#   'ABCBC': 1,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 1,
#   'ABCBD': 10,
#   'ABCBDA': 0,
#   'ABCBDC': 0,
#   'ABCBDB': 2,
#   'ABCBDE': 8,
#   'ABCD': 78,
#   'ABCDA': 3,
#   'ABCDAC': 1,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 1,
#   'ABCDC': 14,
#   'ABCDCA': 1,
#   'ABCDCD': 1,
#   'ABCDCB': 1,
#   'ABCDCE': 10,
#   'ABCDB': 7,
#   'ABCDBA': 3,
#   'ABCDBC': 0,
#   'ABCDBD': 1,
#   'ABCDBE': 2,
#   'ABCDE': 28,
#   'ABCDEA': 1,
#   'ABCDEC': 2,
#   'ABCDED': 1,
#   'ABCDEB': 2,
#   'ABCDEF': 15},
#  'CZECH_REPUBLIC': {'AB': 310,
#   'ABA': 62,
#   'ABC': 215,
#   'ABAB': 10,
#   'ABABA': 0,
#   'ABABC': 6,
#   'ABABCA': 1,
#   'ABABCB': 1,
#   'ABABCD': 1,
#   'ABAC': 40,
#   'ABACA': 3,
#   'ABACAC': 0,
#   'ABACAB': 1,
#   'ABACAD': 2,
#   'ABACB': 0,
#   'ABACD': 17,
#   'ABACDA': 3,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 7,
#   'ABCA': 14,
#   'ABCAC': 3,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 6,
#   'ABCADA': 1,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 1,
#   'ABCB': 30,
#   'ABCBA': 1,
#   'ABCBAC': 0,
#   'ABCBAB': 1,
#   'ABCBAD': 0,
#   'ABCBC': 5,
#   'ABCBCA': 0,
#   'ABCBCB': 2,
#   'ABCBCD': 2,
#   'ABCBD': 21,
#   'ABCBDA': 0,
#   'ABCBDC': 1,
#   'ABCBDB': 4,
#   'ABCBDE': 8,
#   'ABCD': 105,
#   'ABCDA': 11,
#   'ABCDAC': 1,
#   'ABCDAD': 0,
#   'ABCDAB': 3,
#   'ABCDAE': 6,
#   'ABCDC': 11,
#   'ABCDCA': 0,
#   'ABCDCD': 0,
#   'ABCDCB': 3,
#   'ABCDCE': 8,
#   'ABCDB': 11,
#   'ABCDBA': 0,
#   'ABCDBC': 1,
#   'ABCDBD': 0,
#   'ABCDBE': 8,
#   'ABCDE': 43,
#   'ABCDEA': 5,
#   'ABCDEC': 5,
#   'ABCDED': 5,
#   'ABCDEB': 2,
#   'ABCDEF': 18},
#  'TURKEY': {'AB': 181,
#   'ABA': 23,
#   'ABC': 145,
#   'ABAB': 2,
#   'ABABA': 1,
#   'ABABAB': 1,
#   'ABABAC': 0,
#   'ABABC': 1,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 1,
#   'ABAC': 14,
#   'ABACA': 0,
#   'ABACB': 1,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 1,
#   'ABACD': 7,
#   'ABACDA': 0,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 5,
#   'ABCA': 10,
#   'ABCAC': 1,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 2,
#   'ABCABA': 1,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 6,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 6,
#   'ABCB': 19,
#   'ABCBA': 1,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 1,
#   'ABCBC': 4,
#   'ABCBCA': 1,
#   'ABCBCB': 1,
#   'ABCBCD': 2,
#   'ABCBD': 12,
#   'ABCBDA': 1,
#   'ABCBDC': 0,
#   'ABCBDB': 1,
#   'ABCBDE': 7,
#   'ABCD': 84,
#   'ABCDA': 5,
#   'ABCDAC': 0,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 2,
#   'ABCDC': 15,
#   'ABCDCA': 0,
#   'ABCDCD': 1,
#   'ABCDCB': 5,
#   'ABCDCE': 8,
#   'ABCDB': 10,
#   'ABCDBA': 4,
#   'ABCDBC': 0,
#   'ABCDBD': 0,
#   'ABCDBE': 5,
#   'ABCDE': 31,
#   'ABCDEA': 0,
#   'ABCDEC': 4,
#   'ABCDED': 3,
#   'ABCDEB': 1,
#   'ABCDEF': 17},
#  'POLAND': {'AB': 193,
#   'ABA': 44,
#   'ABC': 131,
#   'ABAB': 9,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 0,
#   'ABABC': 2,
#   'ABABCA': 0,
#   'ABABCB': 1,
#   'ABABCD': 0,
#   'ABAC': 24,
#   'ABACA': 4,
#   'ABACAC': 1,
#   'ABACAB': 1,
#   'ABACAD': 1,
#   'ABACB': 0,
#   'ABACD': 13,
#   'ABACDA': 1,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 8,
#   'ABCA': 10,
#   'ABCAC': 0,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 5,
#   'ABCADA': 1,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 4,
#   'ABCB': 19,
#   'ABCBA': 1,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 1,
#   'ABCBC': 3,
#   'ABCBCA': 1,
#   'ABCBCB': 0,
#   'ABCBCD': 2,
#   'ABCBD': 11,
#   'ABCBDA': 1,
#   'ABCBDC': 2,
#   'ABCBDB': 2,
#   'ABCBDE': 4,
#   'ABCD': 64,
#   'ABCDA': 1,
#   'ABCDAC': 0,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 0,
#   'ABCDC': 8,
#   'ABCDCA': 0,
#   'ABCDCD': 0,
#   'ABCDCB': 1,
#   'ABCDCE': 5,
#   'ABCDB': 5,
#   'ABCDBA': 2,
#   'ABCDBC': 1,
#   'ABCDBD': 1,
#   'ABCDBE': 1,
#   'ABCDE': 33,
#   'ABCDEA': 1,
#   'ABCDEC': 2,
#   'ABCDED': 5,
#   'ABCDEB': 2,
#   'ABCDEF': 11},
#  'BELGIUM': {'AB': 316,
#   'ABA': 45,
#   'ABC': 255,
#   'ABAB': 6,
#   'ABABA': 1,
#   'ABABAB': 1,
#   'ABABAC': 0,
#   'ABABC': 3,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 3,
#   'ABAC': 33,
#   'ABACA': 3,
#   'ABACAC': 0,
#   'ABACAB': 1,
#   'ABACAD': 2,
#   'ABACB': 5,
#   'ABACBA': 1,
#   'ABACBC': 2,
#   'ABACBD': 1,
#   'ABACD': 16,
#   'ABACDA': 1,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 11,
#   'ABCA': 11,
#   'ABCAC': 2,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 3,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 2,
#   'ABCAD': 5,
#   'ABCADA': 1,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 2,
#   'ABCB': 40,
#   'ABCBA': 7,
#   'ABCBAC': 2,
#   'ABCBAB': 1,
#   'ABCBAD': 4,
#   'ABCBC': 8,
#   'ABCBCA': 1,
#   'ABCBCB': 1,
#   'ABCBCD': 6,
#   'ABCBD': 23,
#   'ABCBDA': 0,
#   'ABCBDC': 3,
#   'ABCBDB': 6,
#   'ABCBDE': 11,
#   'ABCD': 165,
#   'ABCDA': 9,
#   'ABCDAC': 0,
#   'ABCDAD': 3,
#   'ABCDAB': 3,
#   'ABCDAE': 3,
#   'ABCDC': 24,
#   'ABCDCA': 0,
#   'ABCDCD': 2,
#   'ABCDCB': 4,
#   'ABCDCE': 16,
#   'ABCDB': 14,
#   'ABCDBA': 2,
#   'ABCDBC': 2,
#   'ABCDBD': 0,
#   'ABCDBE': 6,
#   'ABCDE': 88,
#   'ABCDEA': 3,
#   'ABCDEC': 8,
#   'ABCDED': 13,
#   'ABCDEB': 8,
#   'ABCDEF': 36},
#  'FINLAND': {'AB': 165,
#   'ABA': 18,
#   'ABC': 128,
#   'ABAB': 2,
#   'ABABA': 0,
#   'ABABC': 2,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 14,
#   'ABACA': 0,
#   'ABACB': 2,
#   'ABACBA': 1,
#   'ABACBC': 1,
#   'ABACBD': 0,
#   'ABACD': 7,
#   'ABACDA': 2,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 3,
#   'ABCA': 10,
#   'ABCAC': 0,
#   'ABCAB': 1,
#   'ABCABA': 1,
#   'ABCABC': 0,
#   'ABCABD': 0,
#   'ABCAD': 7,
#   'ABCADA': 1,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 4,
#   'ABCB': 25,
#   'ABCBA': 5,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 5,
#   'ABCBC': 10,
#   'ABCBCA': 0,
#   'ABCBCB': 4,
#   'ABCBCD': 3,
#   'ABCBD': 6,
#   'ABCBDA': 0,
#   'ABCBDC': 1,
#   'ABCBDB': 0,
#   'ABCBDE': 4,
#   'ABCD': 58,
#   'ABCDA': 2,
#   'ABCDAC': 0,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 1,
#   'ABCDC': 10,
#   'ABCDCA': 0,
#   'ABCDCD': 1,
#   'ABCDCB': 2,
#   'ABCDCE': 4,
#   'ABCDB': 3,
#   'ABCDBA': 0,
#   'ABCDBC': 0,
#   'ABCDBD': 0,
#   'ABCDBE': 3,
#   'ABCDE': 27,
#   'ABCDEA': 0,
#   'ABCDEC': 3,
#   'ABCDED': 4,
#   'ABCDEB': 3,
#   'ABCDEF': 12},
#  'GERMANY': {'AB': 261,
#   'ABA': 41,
#   'ABC': 210,
#   'ABAB': 7,
#   'ABABA': 0,
#   'ABABC': 5,
#   'ABABCA': 1,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 33,
#   'ABACA': 2,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 2,
#   'ABACB': 3,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 3,
#   'ABACD': 20,
#   'ABACDA': 0,
#   'ABACDC': 3,
#   'ABACDB': 0,
#   'ABACDE': 15,
#   'ABCA': 22,
#   'ABCAC': 1,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 0,
#   'ABCAB': 2,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 2,
#   'ABCAD': 13,
#   'ABCADA': 2,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 7,
#   'ABCB': 25,
#   'ABCBA': 3,
#   'ABCBAC': 0,
#   'ABCBAB': 1,
#   'ABCBAD': 1,
#   'ABCBC': 3,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 3,
#   'ABCBD': 18,
#   'ABCBDA': 1,
#   'ABCBDC': 0,
#   'ABCBDB': 2,
#   'ABCBDE': 8,
#   'ABCD': 139,
#   'ABCDA': 11,
#   'ABCDAC': 1,
#   'ABCDAD': 0,
#   'ABCDAB': 1,
#   'ABCDAE': 8,
#   'ABCDC': 19,
#   'ABCDCA': 2,
#   'ABCDCD': 2,
#   'ABCDCB': 5,
#   'ABCDCE': 6,
#   'ABCDB': 14,
#   'ABCDBA': 4,
#   'ABCDBC': 1,
#   'ABCDBD': 0,
#   'ABCDBE': 8,
#   'ABCDE': 71,
#   'ABCDEA': 5,
#   'ABCDEC': 8,
#   'ABCDED': 14,
#   'ABCDEB': 3,
#   'ABCDEF': 28},
#  'UKRAINE': {'AB': 302,
#   'ABA': 48,
#   'ABC': 247,
#   'ABAB': 11,
#   'ABABA': 3,
#   'ABABAB': 1,
#   'ABABAC': 1,
#   'ABABC': 5,
#   'ABABCA': 1,
#   'ABABCB': 0,
#   'ABABCD': 3,
#   'ABAC': 29,
#   'ABACA': 1,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 1,
#   'ABACB': 3,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 3,
#   'ABACD': 15,
#   'ABACDA': 0,
#   'ABACDC': 3,
#   'ABACDB': 0,
#   'ABACDE': 11,
#   'ABCA': 16,
#   'ABCAC': 0,
#   'ABCAB': 2,
#   'ABCABA': 1,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 11,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 2,
#   'ABCADE': 7,
#   'ABCB': 41,
#   'ABCBA': 2,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 2,
#   'ABCBC': 1,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 1,
#   'ABCBD': 31,
#   'ABCBDA': 2,
#   'ABCBDC': 1,
#   'ABCBDB': 7,
#   'ABCBDE': 21,
#   'ABCD': 153,
#   'ABCDA': 6,
#   'ABCDAC': 0,
#   'ABCDAD': 0,
#   'ABCDAB': 1,
#   'ABCDAE': 5,
#   'ABCDC': 20,
#   'ABCDCA': 1,
#   'ABCDCD': 7,
#   'ABCDCB': 3,
#   'ABCDCE': 8,
#   'ABCDB': 13,
#   'ABCDBA': 0,
#   'ABCDBC': 1,
#   'ABCDBD': 1,
#   'ABCDBE': 10,
#   'ABCDE': 71,
#   'ABCDEA': 1,
#   'ABCDEC': 5,
#   'ABCDED': 10,
#   'ABCDEB': 8,
#   'ABCDEF': 34},
#  'AUSTRIA': {'AB': 310,
#   'ABA': 49,
#   'ABC': 252,
#   'ABAB': 11,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 7,
#   'ABABCA': 2,
#   'ABABCB': 1,
#   'ABABCD': 4,
#   'ABAC': 29,
#   'ABACA': 4,
#   'ABACAC': 0,
#   'ABACAB': 1,
#   'ABACAD': 3,
#   'ABACB': 2,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 1,
#   'ABACD': 10,
#   'ABACDA': 2,
#   'ABACDC': 0,
#   'ABACDB': 1,
#   'ABACDE': 6,
#   'ABCA': 14,
#   'ABCAC': 0,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 1,
#   'ABCAD': 10,
#   'ABCADA': 2,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 6,
#   'ABCB': 41,
#   'ABCBA': 4,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 3,
#   'ABCBC': 7,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 7,
#   'ABCBD': 23,
#   'ABCBDA': 3,
#   'ABCBDC': 2,
#   'ABCBDB': 1,
#   'ABCBDE': 14,
#   'ABCD': 152,
#   'ABCDA': 4,
#   'ABCDAC': 1,
#   'ABCDAD': 0,
#   'ABCDAB': 0,
#   'ABCDAE': 2,
#   'ABCDC': 24,
#   'ABCDCA': 3,
#   'ABCDCD': 1,
#   'ABCDCB': 7,
#   'ABCDCE': 12,
#   'ABCDB': 16,
#   'ABCDBA': 0,
#   'ABCDBC': 1,
#   'ABCDBD': 1,
#   'ABCDBE': 11,
#   'ABCDE': 77,
#   'ABCDEA': 3,
#   'ABCDEC': 6,
#   'ABCDED': 7,
#   'ABCDEB': 7,
#   'ABCDEF': 30},
#  'NETHERLANDS': {'AB': 267,
#   'ABA': 50,
#   'ABC': 196,
#   'ABAB': 9,
#   'ABABA': 2,
#   'ABABAB': 1,
#   'ABABAC': 1,
#   'ABABC': 5,
#   'ABABCA': 0,
#   'ABABCB': 2,
#   'ABABCD': 2,
#   'ABAC': 31,
#   'ABACA': 3,
#   'ABACAC': 0,
#   'ABACAB': 2,
#   'ABACAD': 0,
#   'ABACB': 3,
#   'ABACBA': 0,
#   'ABACBC': 1,
#   'ABACBD': 1,
#   'ABACD': 15,
#   'ABACDA': 1,
#   'ABACDC': 5,
#   'ABACDB': 1,
#   'ABACDE': 7,
#   'ABCA': 18,
#   'ABCAC': 1,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 5,
#   'ABCABA': 2,
#   'ABCABC': 2,
#   'ABCABD': 1,
#   'ABCAD': 9,
#   'ABCADA': 2,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 4,
#   'ABCB': 30,
#   'ABCBA': 4,
#   'ABCBAC': 2,
#   'ABCBAB': 2,
#   'ABCBAD': 0,
#   'ABCBC': 3,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 2,
#   'ABCBD': 19,
#   'ABCBDA': 1,
#   'ABCBDC': 2,
#   'ABCBDB': 3,
#   'ABCBDE': 9,
#   'ABCD': 108,
#   'ABCDA': 6,
#   'ABCDAC': 1,
#   'ABCDAD': 1,
#   'ABCDAB': 0,
#   'ABCDAE': 4,
#   'ABCDC': 17,
#   'ABCDCA': 1,
#   'ABCDCD': 4,
#   'ABCDCB': 4,
#   'ABCDCE': 7,
#   'ABCDB': 12,
#   'ABCDBA': 2,
#   'ABCDBC': 1,
#   'ABCDBD': 1,
#   'ABCDBE': 7,
#   'ABCDE': 47,
#   'ABCDEA': 2,
#   'ABCDEC': 4,
#   'ABCDED': 8,
#   'ABCDEB': 1,
#   'ABCDEF': 18},
#  'HUNGARY': {'AB': 157,
#   'ABA': 33,
#   'ABC': 108,
#   'ABAB': 6,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 5,
#   'ABABCA': 0,
#   'ABABCB': 1,
#   'ABABCD': 2,
#   'ABAC': 19,
#   'ABACA': 4,
#   'ABACAC': 1,
#   'ABACAB': 1,
#   'ABACAD': 1,
#   'ABACB': 2,
#   'ABACBA': 1,
#   'ABACBC': 0,
#   'ABACBD': 1,
#   'ABACD': 6,
#   'ABACDA': 0,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 4,
#   'ABCA': 9,
#   'ABCAC': 2,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 0,
#   'ABCAB': 2,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 2,
#   'ABCAD': 3,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 0,
#   'ABCADE': 1,
#   'ABCB': 17,
#   'ABCBA': 4,
#   'ABCBAC': 1,
#   'ABCBAB': 2,
#   'ABCBAD': 0,
#   'ABCBC': 3,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 3,
#   'ABCBD': 8,
#   'ABCBDA': 0,
#   'ABCBDC': 2,
#   'ABCBDB': 1,
#   'ABCBDE': 4,
#   'ABCD': 52,
#   'ABCDA': 0,
#   'ABCDC': 8,
#   'ABCDCA': 0,
#   'ABCDCD': 0,
#   'ABCDCB': 0,
#   'ABCDCE': 2,
#   'ABCDB': 2,
#   'ABCDBA': 0,
#   'ABCDBC': 0,
#   'ABCDBD': 0,
#   'ABCDBE': 1,
#   'ABCDE': 19,
#   'ABCDEA': 0,
#   'ABCDEC': 2,
#   'ABCDED': 2,
#   'ABCDEB': 1,
#   'ABCDEF': 9},
#  'SWEDEN': {'AB': 196,
#   'ABA': 25,
#   'ABC': 146,
#   'ABAB': 6,
#   'ABABA': 2,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 3,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 13,
#   'ABACA': 2,
#   'ABACAC': 0,
#   'ABACAB': 1,
#   'ABACAD': 1,
#   'ABACB': 1,
#   'ABACBA': 0,
#   'ABACBC': 1,
#   'ABACBD': 0,
#   'ABACD': 3,
#   'ABACDA': 0,
#   'ABACDC': 1,
#   'ABACDB': 0,
#   'ABACDE': 2,
#   'ABCA': 13,
#   'ABCAC': 0,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 0,
#   'ABCAD': 9,
#   'ABCADA': 2,
#   'ABCADC': 1,
#   'ABCADB': 1,
#   'ABCADE': 3,
#   'ABCB': 13,
#   'ABCBA': 0,
#   'ABCBC': 1,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 1,
#   'ABCBD': 10,
#   'ABCBDA': 0,
#   'ABCBDC': 0,
#   'ABCBDB': 3,
#   'ABCBDE': 6,
#   'ABCD': 75,
#   'ABCDA': 7,
#   'ABCDAC': 0,
#   'ABCDAD': 0,
#   'ABCDAB': 1,
#   'ABCDAE': 5,
#   'ABCDC': 5,
#   'ABCDCA': 1,
#   'ABCDCD': 1,
#   'ABCDCB': 2,
#   'ABCDCE': 0,
#   'ABCDB': 6,
#   'ABCDBA': 0,
#   'ABCDBC': 3,
#   'ABCDBD': 1,
#   'ABCDBE': 1,
#   'ABCDE': 37,
#   'ABCDEA': 2,
#   'ABCDEC': 2,
#   'ABCDED': 6,
#   'ABCDEB': 3,
#   'ABCDEF': 15},
#  'SWITZERLAND': {'AB': 348,
#   'ABA': 41,
#   'ABC': 276,
#   'ABAB': 7,
#   'ABABA': 0,
#   'ABABC': 6,
#   'ABABCA': 0,
#   'ABABCB': 1,
#   'ABABCD': 4,
#   'ABAC': 27,
#   'ABACA': 4,
#   'ABACAC': 1,
#   'ABACAB': 1,
#   'ABACAD': 2,
#   'ABACB': 3,
#   'ABACBA': 0,
#   'ABACBC': 1,
#   'ABACBD': 1,
#   'ABACD': 10,
#   'ABACDA': 0,
#   'ABACDC': 2,
#   'ABACDB': 1,
#   'ABACDE': 6,
#   'ABCA': 11,
#   'ABCAC': 1,
#   'ABCACA': 0,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 1,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 0,
#   'ABCAD': 8,
#   'ABCADA': 0,
#   'ABCADC': 0,
#   'ABCADB': 1,
#   'ABCADE': 6,
#   'ABCB': 33,
#   'ABCBA': 4,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 3,
#   'ABCBC': 4,
#   'ABCBCA': 0,
#   'ABCBCB': 2,
#   'ABCBCD': 2,
#   'ABCBD': 21,
#   'ABCBDA': 3,
#   'ABCBDC': 2,
#   'ABCBDB': 0,
#   'ABCBDE': 11,
#   'ABCD': 182,
#   'ABCDA': 11,
#   'ABCDAC': 1,
#   'ABCDAD': 3,
#   'ABCDAB': 1,
#   'ABCDAE': 3,
#   'ABCDC': 29,
#   'ABCDCA': 0,
#   'ABCDCD': 5,
#   'ABCDCB': 3,
#   'ABCDCE': 16,
#   'ABCDB': 18,
#   'ABCDBA': 2,
#   'ABCDBC': 1,
#   'ABCDBD': 6,
#   'ABCDBE': 9,
#   'ABCDE': 75,
#   'ABCDEA': 3,
#   'ABCDEC': 5,
#   'ABCDED': 5,
#   'ABCDEB': 3,
#   'ABCDEF': 42},
#  'DENMARK': {'AB': 408,
#   'ABA': 70,
#   'ABC': 309,
#   'ABAB': 10,
#   'ABABA': 1,
#   'ABABAB': 0,
#   'ABABAC': 1,
#   'ABABC': 7,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 2,
#   'ABAC': 47,
#   'ABACA': 5,
#   'ABACAC': 1,
#   'ABACAB': 3,
#   'ABACAD': 0,
#   'ABACB': 5,
#   'ABACBA': 2,
#   'ABACBC': 1,
#   'ABACBD': 2,
#   'ABACD': 26,
#   'ABACDA': 1,
#   'ABACDC': 3,
#   'ABACDB': 1,
#   'ABACDE': 14,
#   'ABCA': 22,
#   'ABCAC': 2,
#   'ABCACA': 0,
#   'ABCACB': 1,
#   'ABCACD': 1,
#   'ABCAB': 2,
#   'ABCABA': 0,
#   'ABCABC': 0,
#   'ABCABD': 2,
#   'ABCAD': 13,
#   'ABCADA': 0,
#   'ABCADC': 1,
#   'ABCADB': 2,
#   'ABCADE': 7,
#   'ABCB': 30,
#   'ABCBA': 5,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 4,
#   'ABCBC': 3,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 2,
#   'ABCBD': 14,
#   'ABCBDA': 1,
#   'ABCBDC': 0,
#   'ABCBDB': 0,
#   'ABCBDE': 8,
#   'ABCD': 178,
#   'ABCDA': 6,
#   'ABCDAC': 1,
#   'ABCDAD': 2,
#   'ABCDAB': 0,
#   'ABCDAE': 2,
#   'ABCDC': 20,
#   'ABCDCA': 1,
#   'ABCDCD': 0,
#   'ABCDCB': 4,
#   'ABCDCE': 12,
#   'ABCDB': 20,
#   'ABCDBA': 2,
#   'ABCDBC': 2,
#   'ABCDBD': 4,
#   'ABCDBE': 6,
#   'ABCDE': 83,
#   'ABCDEA': 0,
#   'ABCDEC': 10,
#   'ABCDED': 15,
#   'ABCDEB': 6,
#   'ABCDEF': 33},
#  'FRANCE': {'AB': 245,
#   'ABA': 44,
#   'ABC': 189,
#   'ABAB': 9,
#   'ABABA': 0,
#   'ABABC': 7,
#   'ABABCA': 0,
#   'ABABCB': 1,
#   'ABABCD': 6,
#   'ABAC': 27,
#   'ABACA': 1,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 1,
#   'ABACB': 3,
#   'ABACBA': 0,
#   'ABACBC': 0,
#   'ABACBD': 2,
#   'ABACD': 18,
#   'ABACDA': 2,
#   'ABACDC': 2,
#   'ABACDB': 1,
#   'ABACDE': 13,
#   'ABCA': 17,
#   'ABCAC': 2,
#   'ABCACA': 1,
#   'ABCACB': 1,
#   'ABCACD': 0,
#   'ABCAB': 3,
#   'ABCABA': 1,
#   'ABCABC': 0,
#   'ABCABD': 0,
#   'ABCAD': 9,
#   'ABCADA': 0,
#   'ABCADC': 1,
#   'ABCADB': 1,
#   'ABCADE': 7,
#   'ABCB': 23,
#   'ABCBA': 2,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 2,
#   'ABCBC': 3,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 2,
#   'ABCBD': 13,
#   'ABCBDA': 0,
#   'ABCBDC': 1,
#   'ABCBDB': 3,
#   'ABCBDE': 8,
#   'ABCD': 117,
#   'ABCDA': 3,
#   'ABCDAC': 0,
#   'ABCDAD': 0,
#   'ABCDAB': 0,
#   'ABCDAE': 3,
#   'ABCDC': 14,
#   'ABCDCA': 2,
#   'ABCDCD': 4,
#   'ABCDCB': 5,
#   'ABCDCE': 2,
#   'ABCDB': 10,
#   'ABCDBA': 1,
#   'ABCDBC': 2,
#   'ABCDBD': 2,
#   'ABCDBE': 3,
#   'ABCDE': 70,
#   'ABCDEA': 1,
#   'ABCDEC': 6,
#   'ABCDED': 14,
#   'ABCDEB': 6,
#   'ABCDEF': 33},
#  'RUSSIA': {'AB': 185,
#   'ABA': 19,
#   'ABC': 152,
#   'ABAB': 5,
#   'ABABA': 2,
#   'ABABAB': 1,
#   'ABABAC': 0,
#   'ABABC': 3,
#   'ABABCA': 0,
#   'ABABCB': 0,
#   'ABABCD': 1,
#   'ABAC': 10,
#   'ABACA': 2,
#   'ABACAC': 0,
#   'ABACAB': 0,
#   'ABACAD': 2,
#   'ABACB': 0,
#   'ABACD': 2,
#   'ABACDA': 0,
#   'ABACDC': 0,
#   'ABACDB': 0,
#   'ABACDE': 1,
#   'ABCA': 5,
#   'ABCAC': 2,
#   'ABCACA': 1,
#   'ABCACB': 0,
#   'ABCACD': 1,
#   'ABCAB': 0,
#   'ABCAD': 3,
#   'ABCADA': 1,
#   'ABCADC': 1,
#   'ABCADB': 0,
#   'ABCADE': 1,
#   'ABCB': 14,
#   'ABCBA': 1,
#   'ABCBAC': 0,
#   'ABCBAB': 0,
#   'ABCBAD': 1,
#   'ABCBC': 3,
#   'ABCBCA': 0,
#   'ABCBCB': 0,
#   'ABCBCD': 3,
#   'ABCBD': 8,
#   'ABCBDA': 0,
#   'ABCBDC': 0,
#   'ABCBDB': 1,
#   'ABCBDE': 7,
#   'ABCD': 92,
#   'ABCDA': 2,
#   'ABCDAC': 1,
#   'ABCDAD': 0,
#   'ABCDAB': 0,
#   'ABCDAE': 1,
#   'ABCDC': 9,
#   'ABCDCA': 1,
#   'ABCDCD': 1,
#   'ABCDCB': 1,
#   'ABCDCE': 4,
#   'ABCDB': 5,
#   'ABCDBA': 2,
#   'ABCDBC': 0,
#   'ABCDBD': 0,
#   'ABCDBE': 1,
#   'ABCDE': 44,
#   'ABCDEA': 2,
#   'ABCDEC': 4,
#   'ABCDED': 6,
#   'ABCDEB': 1,
#   'ABCDEF': 21}}

# %%
import json
json.dump(result, open("sunburst_unconstrained.json", "w"))

# %%
patterns = []
prefixes = []
values = []
colors = []
for res in result["SPAIN"]:
    
        patterns.append(res)
        prefixes.append(res[:-1])
        values.append(result["SPAIN"][res])
        colors.append(res[0:4] if len(res)>=4 else  12)
        
prefixes[0] = ""

data = dict(
patterns= patterns,
prefixes= prefixes,
values= values
)

# %%
colors
# Out:
# [12,
#  12,
#  12,
#  'ABAB',
#  'ABAB',
#  'ABAB',
#  'ABAB',
#  'ABAB',
#  'ABAB',
#  'ABAB',
#  'ABAB',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABAC',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCA',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCB',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD',
#  'ABCD']

# %%
import plotly.express as px


fig = px.sunburst(data,
    names="patterns",
    parents="prefixes",
    values="values",
    color = prefixes
)
fig.show()
# Out:
# <div>                            <div id="e07d8c3f-e57d-439a-947e-7526d7438715" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e07d8c3f-e57d-439a-947e-7526d7438715")) {                    Plotly.newPlot(                        "e07d8c3f-e57d-439a-947e-7526d7438715",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "patterns=%{label}<br>value=%{value}<br>prefixes=%{parent}<extra></extra>", "labels": ["AB", "ABA", "ABC", "ABAB", "ABABA", "ABABAB", "ABABAC", "ABABC", "ABABCA", "ABABCB", "ABABCD", "ABAC", "ABACA", "ABACAC", "ABACAB", "ABACAD", "ABACB", "ABACBA", "ABACBC", "ABACBD", "ABACD", "ABACDA", "ABACDC", "ABACDB", "ABACDE", "ABCA", "ABCAC", "ABCACA", "ABCACB", "ABCACD", "ABCAB", "ABCABA", "ABCABC", "ABCABD", "ABCAD", "ABCADA", "ABCADC", "ABCADB", "ABCADE", "ABCB", "ABCBA", "ABCBAC", "ABCBAB", "ABCBAD", "ABCBC", "ABCBCA", "ABCBCB", "ABCBCD", "ABCBD", "ABCBDA", "ABCBDC", "ABCBDB", "ABCBDE", "ABCD", "ABCDA", "ABCDAC", "ABCDAD", "ABCDAB", "ABCDAE", "ABCDC", "ABCDCA", "ABCDCD", "ABCDCB", "ABCDCE", "ABCDB", "ABCDBA", "ABCDBC", "ABCDBD", "ABCDBE", "ABCDE", "ABCDEA", "ABCDEC", "ABCDED", "ABCDEB", "ABCDEF"], "marker": {"colors": ["#636efa", "#EF553B", "#EF553B", "#00cc96", "#ab63fa", "#FFA15A", "#FFA15A", "#ab63fa", "#19d3f3", "#19d3f3", "#19d3f3", "#00cc96", "#FF6692", "#B6E880", "#B6E880", "#B6E880", "#FF6692", "#FF97FF", "#FF97FF", "#FF97FF", "#FF6692", "#FECB52", "#FECB52", "#FECB52", "#FECB52", "#636efa", "#EF553B", "#00cc96", "#00cc96", "#00cc96", "#EF553B", "#ab63fa", "#ab63fa", "#ab63fa", "#EF553B", "#FFA15A", "#FFA15A", "#FFA15A", "#FFA15A", "#636efa", "#19d3f3", "#FF6692", "#FF6692", "#FF6692", "#19d3f3", "#B6E880", "#B6E880", "#B6E880", "#19d3f3", "#FF97FF", "#FF97FF", "#FF97FF", "#FF97FF", "#636efa", "#FECB52", "#636efa", "#636efa", "#636efa", "#636efa", "#FECB52", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#FECB52", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#FECB52", "#ab63fa", "#ab63fa", "#ab63fa", "#ab63fa", "#ab63fa"]}, "name": "", "parents": ["", "AB", "AB", "ABA", "ABAB", "ABABA", "ABABA", "ABAB", "ABABC", "ABABC", "ABABC", "ABA", "ABAC", "ABACA", "ABACA", "ABACA", "ABAC", "ABACB", "ABACB", "ABACB", "ABAC", "ABACD", "ABACD", "ABACD", "ABACD", "ABC", "ABCA", "ABCAC", "ABCAC", "ABCAC", "ABCA", "ABCAB", "ABCAB", "ABCAB", "ABCA", "ABCAD", "ABCAD", "ABCAD", "ABCAD", "ABC", "ABCB", "ABCBA", "ABCBA", "ABCBA", "ABCB", "ABCBC", "ABCBC", "ABCBC", "ABCB", "ABCBD", "ABCBD", "ABCBD", "ABCBD", "ABC", "ABCD", "ABCDA", "ABCDA", "ABCDA", "ABCDA", "ABCD", "ABCDC", "ABCDC", "ABCDC", "ABCDC", "ABCD", "ABCDB", "ABCDB", "ABCDB", "ABCDB", "ABCD", "ABCDE", "ABCDE", "ABCDE", "ABCDE", "ABCDE"], "type": "sunburst", "values": [499, 71, 404, 20, 1, 0, 1, 16, 3, 4, 9, 44, 5, 0, 2, 2, 6, 0, 0, 5, 20, 0, 1, 1, 11, 39, 4, 0, 0, 4, 2, 0, 0, 2, 28, 0, 3, 2, 18, 55, 7, 0, 5, 2, 5, 1, 1, 3, 39, 3, 1, 6, 19, 255, 11, 1, 2, 2, 4, 38, 4, 8, 8, 16, 26, 3, 5, 3, 12, 148, 10, 14, 30, 5, 66]}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorsca ...
